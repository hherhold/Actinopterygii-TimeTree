# %% [markdown]
# # Ray-finned fish tree from TimeTree - species level (Actinopterygii)
#
# The goal of this notebook is to produce a clean species tree that is annotated
# with orders and families in internal node names. It also produces an order-level
# tree with the orders as the leaves that will serve as a scaffold in successive
# notebooks.
#
# To accomplish this, we need to look up the order and family for every species in
# the tree. This requires some cleaning of the tree, which is removing taxa that
# cannot be looked up and fixing node names so lookups can be done properly. It
# also involves cleaning of the database, which is an iterative process. The final
# version of this notebook is after all this has been done. The taxonomy database
# is saved locally during this process and the final db has been tweaked quite a
# bit.
#
# This script requires ETE, which normally does not install properly on Windows.
# You can run it in Windows, but you have to install ETE carefully and with the
# right prerequisites. You may have issues running a blanket `import ete`, as this
# pulls in all kinds of things that don't work on windows. Here I only use the
# `Tree` class, which appears to work.

# %%
# Let's use my handy dandy taxonomy database to look up order and family info.

import TaxonomyDB as taxonomydb
from importlib import reload
reload(taxonomydb)

# Get the hostname to help set the data directory correctly.
import socket
hostname = socket.gethostname()
print("Hostname:", hostname)

if hostname == "RGGS-LAP-005":
    db = taxonomydb.TaxonomyDB(data_dir="e:/NCBI_taxdump")
else:
    db = taxonomydb.TaxonomyDB(data_dir="c:/Users/hherhold/Data/NCBI_taxdump")
# Out:
# Hostname: AMNH-WSJ8DDFB4
# Loading NCBI taxonomy data...done.

# %% [markdown]
# Quick database test...

# %%
db.get_species_info("Calamus")
# Out:
# Cache hit for genus 'Calamus': Order: Acanthuriformes, Family: Sparidae
# ('Acanthuriformes', 'Sparidae')

# %% [markdown]
# Database cleanup. Problematic taxa identified on previous runs. This only needs to be run once as the DB caches changes locally. Running it multiple times doesn't hurt anything, you just don't need to do it.

# %%
# Extra taxa not in GBIF or NCBI that we need to handle.
db.remove_species_info(genus='Calamus')
db.remove_species_info(genus='Ophidion')
db.remove_species_info(genus='Liparis')
db.remove_species_info(genus='Orestias')
db.remove_species_info(genus='Scuticaria')
db.remove_species_info(genus='Centropogon')
db.remove_species_info(genus='Exostoma')
db.remove_species_info(genus='Mora')
db.remove_species_info(genus='Bullockia')
db.remove_species_info(genus='Symphysodon')
db.remove_species_info(genus='Scleronema')
db.remove_species_info(genus='Histrio')
db.remove_species_info(genus='Nansenia')
db.remove_species_info(genus='Olyra')
db.remove_species_info(genus='Cynodon')
db.remove_species_info(genus='Bairdiella')
db.remove_species_info(genus='Ranzania')
db.remove_species_info(genus='Zeus')
db.remove_species_info(genus='Argentina')
db.remove_species_info(genus='Dactylophora')
db.remove_species_info(genus='Trachystoma')

db.add_species_info('Calamus', 'Acanthuriformes', 'Sparidae')
db.add_species_info('Ophidion', 'Ophidiiformes', 'Ophidiidae')
db.add_species_info('Liparis', 'Perciformes', 'Liparidae')
db.add_species_info('Orestias', 'Cyprinodontiformes', 'Cyprinodontidae')
db.add_species_info('Scuticaria', 'Anguilliformes', 'Muraenidae')
db.add_species_info('Centropogon', 'Perciformes', 'Syngnathidae')
db.add_species_info('Exostoma', 'Siluriformes', 'Sisoridae')
db.add_species_info('Mora', 'Gadiformes', 'Moridae')
db.add_species_info('Bullockia', 'Siluriformes', 'Tricomycteridae')
db.add_species_info('Symphysodon', 'Cichliformes', 'Cichlidae')
db.add_species_info('Scleronema', 'Siluriformes', 'Trichomycteridae')
db.add_species_info('Histrio', 'Lophiiformes', 'Antennariidae')
db.add_species_info('Nansenia', 'Argentiniformes', 'Microstomatidae')
db.add_species_info('Olyra', 'Siluriformes', 'Bagridae')
db.add_species_info('Cynodon', 'Characiformes', 'Cynodontidae')
db.add_species_info('Bairdiella', 'Acanthuriformes', 'Sciaenidae')
db.add_species_info('Ranzania', 'Tetraodontiformes', 'Molidae')
db.add_species_info('Zeus', 'Zeiformes', 'Zeidae')
db.add_species_info('Argentina', 'Argentiniformes', 'Argentinidae')
db.add_species_info('Dactylophora', 'Centrarchiformes', 'Cheilodactylidae')
db.add_species_info('Trachystoma', 'Mugiliformes', 'Mugilidae')
# Out:
# Removed Calamus from the database.
# Removed Ophidion from the database.
# Removed Liparis from the database.
# Removed Orestias from the database.
# Removed Scuticaria from the database.
# Removed Centropogon from the database.
# Removed Exostoma from the database.
# Removed Mora from the database.
# Removed Bullockia from the database.
# Removed Symphysodon from the database.
# Removed Scleronema from the database.
# Removed Histrio from the database.
# Removed Nansenia from the database.
# Removed Olyra from the database.
# Removed Cynodon from the database.
# Removed Bairdiella from the database.
# Removed Ranzania from the database.
# Removed Zeus from the database.
# Removed Argentina from the database.
# Removed Dactylophora from the database.
# Removed Trachystoma from the database.
# Added Calamus to the database with Order: Acanthuriformes, Family: Sparidae
# Added Ophidion to the database with Order: Ophidiiformes, Family: Ophidiidae
# Added Liparis to the database with Order: Perciformes, Family: Liparidae
# Added Orestias to the database with Order: Cyprinodontiformes, Family: Cyprinodontidae
# Added Scuticaria to the database with Order: Anguilliformes, Family: Muraenidae
# Added Centropogon to the database with Order: Perciformes, Family: Syngnathidae
# Added Exostoma to the database with Order: Siluriformes, Family: Sisoridae
# Added Mora to the database with Order: Gadiformes, Family: Moridae
# Added Bullockia to the database with Order: Siluriformes, Family: Tricomycteridae
# Added Symphysodon to the database with Order: Cichliformes, Family: Cichlidae
# Added Scleronema to the database with Order: Siluriformes, Family: Trichomycteridae
# Added Histrio to the database with Order: Lophiiformes, Family: Antennariidae
# Added Nansenia to the database with Order: Argentiniformes, Family: Microstomatidae
# Added Olyra to the database with Order: Siluriformes, Family: Bagridae
# Added Cynodon to the database with Order: Characiformes, Family: Cynodontidae
# Added Bairdiella to the database with Order: Acanthuriformes, Family: Sciaenidae
# Added Ranzania to the database with Order: Tetraodontiformes, Family: Molidae
# Added Zeus to the database with Order: Zeiformes, Family: Zeidae
# Added Argentina to the database with Order: Argentiniformes, Family: Argentinidae
# Added Dactylophora to the database with Order: Centrarchiformes, Family: Cheilodactylidae
# Added Trachystoma to the database with Order: Mugiliformes, Family: Mugilidae

# %%
# Load in the trees.

from ete3 import Tree

species_tree = Tree('ray-finned fishes_species.nwk', format=1, quoted_node_names=True)

# Output the number of tips in each tree.
print(f'Species tree has {len(species_tree.get_leaves())} tips.')
# Out:
# Species tree has 15180 tips.

# %% [markdown]
# ## Data cleaning
#
# Trees from timetree.org are a composite of many trees from different studies. Some of these have odd naming schemes and don't conform to "Genus species" naming like we need here for lookups. This section of code cleans up names so that lookups for family and order actually work.
#
# Every dataset is a little different, and the code blocks below are specific to *this* dataset. Cleanup of the insect tree was quite different, as there were many misnamed genera and even some bacteria included. Oh, and some fungi, and a couple of bivalves.

# %%
# There are a few family names posing as genera. Remove anything that
# ends with "idae" or "inae".

import re

for leaf in species_tree.get_leaves():
    # Grab the first part of the name. It can be the first word separated by a space,
    # underscore, or dash.
    genus_name = re.split(r'[ _-]', leaf.name)[0]

    # If the genus name ends with "idae" or "inae", remove it.
    if genus_name.endswith("idae") or genus_name.endswith("inae"):
        print(f"Removing family name posing as genus: {genus_name}")
        species_tree.search_nodes(name=leaf.name)[0].detach()
# Out:
# Removing family name posing as genus: Thaumatichthyidae
# Removing family name posing as genus: Ereuniidae
# Removing family name posing as genus: Anomalopidae
# Removing family name posing as genus: Hypostominae
# Removing family name posing as genus: Neoplecostominae
# Removing family name posing as genus: Neoplecostominae

# %%
# Are there any leaves that are just a number, or just an underscore and a number?
for leaf in species_tree.get_leaves():
    if re.match(r'^_?\d+$', leaf.name):
        print(f"Removing invalid leaf name: {leaf.name}")
        species_tree.search_nodes(name=leaf.name)[0].detach()
# Out:
# Removing invalid leaf name: _1895

# %%
# Misspellings. 

for leaf in species_tree.get_leaves():
    # Labeoarbus -> Labeobarbus
    if leaf.name.startswith("Labeoarbus"):
        print(f"Correcting misspelled genus: {leaf.name} -> Labeobarbus")
        species_tree.search_nodes(name=leaf.name)[0].name = leaf.name.replace("Labeoarbus", "Labeobarbus")

    # Tariqlabeo -> Tariqilabeo
    if leaf.name.startswith("Tariqlabeo"):
        print(f"Correcting misspelled genus: {leaf.name} -> Tariqilabeo")
        species_tree.search_nodes(name=leaf.name)[0].name = leaf.name.replace("Tariqlabeo", "Tariqilabeo")
# Out:
# Correcting misspelled genus: Labeoarbus_bynni_occidentalis -> Labeobarbus
# Correcting misspelled genus: Tariqlabeo_bicornis -> Tariqilabeo

# %%
# Inactive taxa.
#Coelonotus_leiaspis should be Microphis_leiaspis
for leaf in species_tree.get_leaves():
    if leaf.name.startswith("Coelonotus_leiaspis"):
        print(f"Correcting inactive taxon: {leaf.name} -> Microphis_leiaspis")
        species_tree.search_nodes(name=leaf.name)[0].name = leaf.name.replace("Coelonotus_leiaspis", "Microphis_leiaspis")
# Out:
# Correcting inactive taxon: Coelonotus_leiaspis -> Microphis_leiaspis

# %%
# Let's make sure there are no duplicated names in the tree. Check all tips - the internal nodes are not important for this.
# Print the list of duplicated names, if any. Also print how many times each duplicated name appears.
tip_names = [leaf.name for leaf in species_tree.iter_leaves()]
duplicated_names = set([name for name in tip_names if tip_names.count(name) > 1])
print("Duplicated names and their counts:")
for name in duplicated_names:
    print(f"{name}: {tip_names.count(name)}")
# Out:
# Duplicated names and their counts:
# Tenebrosternarchus_preto: 2

# %%
# There's only one, Tenebrosternarchus_preto. Get the list of all leaves with that name.
tenebrosternarchus_leaves = species_tree.search_nodes(name="Tenebrosternarchus_preto")
print(f"Found {len(tenebrosternarchus_leaves)} leaves with the name 'Tenebrosternarchus_preto'.")

# Rename them to Tenebrosternarchus_preto_1 and Tenebrosternarchus_preto_2.
count = 1
for leaf in species_tree.get_leaves():
    if leaf.name == "Tenebrosternarchus_preto":
        new_name = f"Tenebrosternarchus_preto_{count}"
        print(f"Renaming duplicate species: {leaf.name} -> {new_name}")
        species_tree.search_nodes(name=leaf.name)[0].name = new_name
        count += 1

# Check for duplicates again.
tip_names = [leaf.name for leaf in species_tree.iter_leaves()]
duplicated_names = set([name for name in tip_names if tip_names.count(name) > 1])
print("Duplicated names after renaming:", duplicated_names)
# Out:
# Found 2 leaves with the name 'Tenebrosternarchus_preto'.
# Renaming duplicate species: Tenebrosternarchus_preto -> Tenebrosternarchus_preto_1
# Duplicated names after renaming: set()

# %%
# A couple of names are quoted because there are spaces in the name. Remove the quotes
# and replace spaces with underscores. Also remove any commas, periods, and parenthesis, and colons.
for leaf in species_tree.get_leaves():
    cleaned_name = leaf.name.replace(" ", "_").replace(",", "").replace(".", "").replace("(", "").replace(")", "").replace(":", "")
    if cleaned_name != leaf.name:
        print(f"Cleaning leaf name: {leaf.name} -> {cleaned_name}")
        species_tree.search_nodes(name=leaf.name)[0].name = cleaned_name
# Out:
# Cleaning leaf name: Photopectoralis_cf._aureus_MPD-2011 -> Photopectoralis_cf_aureus_MPD-2011
# Cleaning leaf name: Photopectoralis_sp._Okinawa/Taiwan -> Photopectoralis_sp_Okinawa/Taiwan
# Cleaning leaf name: Leiognathus_sp._Fiji -> Leiognathus_sp_Fiji
# Cleaning leaf name: Lutjanus_sp._2_PM-2004 -> Lutjanus_sp_2_PM-2004
# Cleaning leaf name: Lutjanus_sp._1_PM-2004 -> Lutjanus_sp_1_PM-2004
# Cleaning leaf name: Lutjanus_cf._apodus_MAR-2011 -> Lutjanus_cf_apodus_MAR-2011
# Cleaning leaf name: Haemulon_sp._A_JJT-2012 -> Haemulon_sp_A_JJT-2012
# Cleaning leaf name: Haemulon_sp._B_JJT-2012 -> Haemulon_sp_B_JJT-2012
# Cleaning leaf name: Anisotremus_aff._interruptus_JT-2018 -> Anisotremus_aff_interruptus_JT-2018
# Cleaning leaf name: Anisotremus_aff._scapularis_JT-2018 -> Anisotremus_aff_scapularis_JT-2018
# Cleaning leaf name: Acanthopagrus_sp._KPM-NR0043453 -> Acanthopagrus_sp_KPM-NR0043453
# Cleaning leaf name: Mola_cf._ramsayi_SAK-2005 -> Mola_cf_ramsayi_SAK-2005
# Cleaning leaf name: Chaunax_sp._VAD-2015 -> Chaunax_sp_VAD-2015
# Cleaning leaf name: Chaunax_cf._abei_VAD-2015 -> Chaunax_cf_abei_VAD-2015
# Cleaning leaf name: Chaunax_sp._UW_025870 -> Chaunax_sp_UW_025870
# Cleaning leaf name: Diceratias_sp.UW -> Diceratias_spUW
# Cleaning leaf name: Ceratias_sp._KU_00940 -> Ceratias_sp_KU_00940
# Cleaning leaf name: Gigantactis_sp._UW_46116 -> Gigantactis_sp_UW_46116
# Cleaning leaf name: Halieutaea_sp._VAD-2015 -> Halieutaea_sp_VAD-2015
# Cleaning leaf name: Solocisquama_sp._VAD-2015 -> Solocisquama_sp_VAD-2015
# Cleaning leaf name: Antennarius_sp._VAD-2015 -> Antennarius_sp_VAD-2015
# Cleaning leaf name: Atractoscion_aff._nobilis_JTT-2012 -> Atractoscion_aff_nobilis_JTT-2012
# Cleaning leaf name: Pachypops_sp._Tapajos -> Pachypops_sp_Tapajos
# Cleaning leaf name: Plagioscion_sp._1_GMC-2012 -> Plagioscion_sp_1_GMC-2012
# Cleaning leaf name: Plagioscion_sp._2_GMC-2012 -> Plagioscion_sp_2_GMC-2012
# Cleaning leaf name: Hapalogenys_sp._MDS-2011 -> Hapalogenys_sp_MDS-2011
# Cleaning leaf name: Enigmapercis_sp.Nsmt -> Enigmapercis_spNsmt
# Cleaning leaf name: Iniistius_sp._LH-2022 -> Iniistius_sp_LH-2022
# Cleaning leaf name: Choerodon cf. gymnogenys BOLD:AAJ0249 -> Choerodon_cf_gymnogenys_BOLDAAJ0249
# Cleaning leaf name: Nemadactylus_sp._n._NMNZ_P.031124/2 -> Nemadactylus_sp_n_NMNZ_P031124/2
# Cleaning leaf name: Cirrhitops_sp._JKS-2008 -> Cirrhitops_sp_JKS-2008
# Cleaning leaf name: Centropogon australis (White, 1790) -> Centropogon_australis_White_1790
# Cleaning leaf name: Paraliparis_sp._beani -> Paraliparis_sp_beani
# Cleaning leaf name: Pseudoliparis_sp.Yap -> Pseudoliparis_spYap
# Cleaning leaf name: Hypoplectrodes_sp._C_LL-2022 -> Hypoplectrodes_sp_C_LL-2022
# Cleaning leaf name: Hypoplectrodes_sp._B_NMNZ_P.041009 -> Hypoplectrodes_sp_B_NMNZ_P041009
# Cleaning leaf name: Hypoplectrodes_sp._A_NMNZ_P.042464 -> Hypoplectrodes_sp_A_NMNZ_P042464
# Cleaning leaf name: Pristolepis_sp._UF_11555 -> Pristolepis_sp_UF_11555
# Cleaning leaf name: Nandus_cf._oxyrhynchus_RH-2021 -> Nandus_cf_oxyrhynchus_RH-2021
# Cleaning leaf name: Channa_cf._maculata_EASA-2010 -> Channa_cf_maculata_EASA-2010
# Cleaning leaf name: Betta_cf._burdigala -> Betta_cf_burdigala
# Cleaning leaf name: Betta_cf._albimarginata_Malinau -> Betta_cf_albimarginata_Malinau
# Cleaning leaf name: Mastacembelus_aff._micropectus_SA80012 -> Mastacembelus_aff_micropectus_SA80012
# Cleaning leaf name: Mastacembelus_sp._SA79846-1 -> Mastacembelus_sp_SA79846-1
# Cleaning leaf name: Mastacembelus_aff._platysoma_SA77443 -> Mastacembelus_aff_platysoma_SA77443
# Cleaning leaf name: Mastacembelus_sp._CU93446 -> Mastacembelus_sp_CU93446
# Cleaning leaf name: Mastacembelus_sp._SA77238 -> Mastacembelus_sp_SA77238
# Cleaning leaf name: Mastacembelus_sp._SA85576 -> Mastacembelus_sp_SA85576
# Cleaning leaf name: Mastacembelus_cf._frenatus_SA73321 -> Mastacembelus_cf_frenatus_SA73321
# Cleaning leaf name: Mastacembelus_cf._frenatus_SA81489 -> Mastacembelus_cf_frenatus_SA81489
# Cleaning leaf name: Nematops_sp._PNG793 -> Nematops_sp_PNG793
# Cleaning leaf name: Symphurus_sp._rafinesque -> Symphurus_sp_rafinesque
# Cleaning leaf name: Tetrapturus_sp._JRM-2006 -> Tetrapturus_sp_JRM-2006
# Cleaning leaf name: Crenicichla_aff._Orinoco_lugubris -> Crenicichla_aff_Orinoco_lugubris
# Cleaning leaf name: Crenicichla_cf._inpa_LP-2021 -> Crenicichla_cf_inpa_LP-2021
# Cleaning leaf name: Crenicichla_cf._alta_C601 -> Crenicichla_cf_alta_C601
# Cleaning leaf name: Crenicichla_cf._alta_LP-2021 -> Crenicichla_cf_alta_LP-2021
# Cleaning leaf name: Crenicichla_aff._menezesi_C679 -> Crenicichla_aff_menezesi_C679
# Cleaning leaf name: Crenicichla_sp._Inirida_I -> Crenicichla_sp_Inirida_I
# Cleaning leaf name: Crenicichla_cf._edithae_C224 -> Crenicichla_cf_edithae_C224
# Cleaning leaf name: Crenicichla_cf._semicincta_LP-2021 -> Crenicichla_cf_semicincta_LP-2021
# Cleaning leaf name: Crenicichla_cf._saxatilis_LP-2021 -> Crenicichla_cf_saxatilis_LP-2021
# Cleaning leaf name: Crenicichla_aff._sveni_C254 -> Crenicichla_aff_sveni_C254
# Cleaning leaf name: Crenicichla_sp._Inirida_III -> Crenicichla_sp_Inirida_III
# Cleaning leaf name: Crenicichla_sp._Caura_2 -> Crenicichla_sp_Caura_2
# Cleaning leaf name: Crenicichla_cf._anthurus_LP-2021 -> Crenicichla_cf_anthurus_LP-2021
# Cleaning leaf name: Crenicichla_aff._Orinoco_wallacii -> Crenicichla_aff_Orinoco_wallacii
# Cleaning leaf name: Crenicichla_cf._dorsocellata_LP-2021 -> Crenicichla_cf_dorsocellata_LP-2021
# Cleaning leaf name: Crenicichla_sp._Chapa -> Crenicichla_sp_Chapa
# Cleaning leaf name: Crenicichla_sp._Uruguai_line -> Crenicichla_sp_Uruguai_line
# Cleaning leaf name: Crenicichla_aff._mandelburgeri_Garupa_E1-62 -> Crenicichla_aff_mandelburgeri_Garupa_E1-62
# Cleaning leaf name: Crenicichla_aff._mandelburgeri_Encarnacion -> Crenicichla_aff_mandelburgeri_Encarnacion
# Cleaning leaf name: Crenicichla_aff._mandelburgeri_Garupa_E1-65 -> Crenicichla_aff_mandelburgeri_Garupa_E1-65
# Cleaning leaf name: Crenicichla_aff._mandelburgeri_Pirayuy -> Crenicichla_aff_mandelburgeri_Pirayuy
# Cleaning leaf name: Crenicichla_aff._mandelburgeri_Tucangua_E1-62 -> Crenicichla_aff_mandelburgeri_Tucangua_E1-62
# Cleaning leaf name: Crenicichla_aff._mandelburgeri_Cunapiru -> Crenicichla_aff_mandelburgeri_Cunapiru
# Cleaning leaf name: Crenicichla_aff._mandelburgeri_Tucangua -> Crenicichla_aff_mandelburgeri_Tucangua
# Cleaning leaf name: Crenicichla_aff._mandelburgeri_Tabay_downE1-58 -> Crenicichla_aff_mandelburgeri_Tabay_downE1-58
# Cleaning leaf name: Crenicichla_aff._mandelburgeri_Tabay_down -> Crenicichla_aff_mandelburgeri_Tabay_down
# Cleaning leaf name: Crenicichla_aff._mandelburgeri_Tabay_up -> Crenicichla_aff_mandelburgeri_Tabay_up
# Cleaning leaf name: Crenicichla_sp._Piray-Guazu -> Crenicichla_sp_Piray-Guazu
# Cleaning leaf name: Crenicichla_sp._Piray-Guazu_line -> Crenicichla_sp_Piray-Guazu_line
# Cleaning leaf name: Crenicichla_aff._geayi_Caura -> Crenicichla_aff_geayi_Caura
# Cleaning leaf name: Crenicichla_cf._jegui_LP-2021 -> Crenicichla_cf_jegui_LP-2021
# Cleaning leaf name: Crenicichla_sp._Gurupi -> Crenicichla_sp_Gurupi
# Cleaning leaf name: Crenicichla_cf._reticulata_C685 -> Crenicichla_cf_reticulata_C685
# Cleaning leaf name: Crenicichla_aff._reticulata_RioBranco -> Crenicichla_aff_reticulata_RioBranco
# Cleaning leaf name: Crenicichla_cf._cyanonotus_C65 -> Crenicichla_cf_cyanonotus_C65
# Cleaning leaf name: Teleocichla_sp._Xingu_IV -> Teleocichla_sp_Xingu_IV
# Cleaning leaf name: Teleocichla_sp._Xingu_III -> Teleocichla_sp_Xingu_III
# Cleaning leaf name: Guianacara_sp._Takutu -> Guianacara_sp_Takutu
# Cleaning leaf name: Geophagus_sp._Cuyuni -> Geophagus_sp_Cuyuni
# Cleaning leaf name: Bujurquina_aff._apoparuana_HLF-2010 -> Bujurquina_aff_apoparuana_HLF-2010
# Cleaning leaf name: Bujurquina_aff._hophrys_HLF-2010 -> Bujurquina_aff_hophrys_HLF-2010
# Cleaning leaf name: Laetacara_sp._Buckelkopf -> Laetacara_sp_Buckelkopf
# Cleaning leaf name: Krobia_sp._Xingu -> Krobia_sp_Xingu
# Cleaning leaf name: Thorichthys_sp._LP-2013 -> Thorichthys_sp_LP-2013
# Cleaning leaf name: Thorichthys_cf._helleri_K60M36 -> Thorichthys_cf_helleri_K60M36
# Cleaning leaf name: Amphilophus_cf._alfari_ba -> Amphilophus_cf_alfari_ba
# Cleaning leaf name: Heros_sp._common -> Heros_sp_common
# Cleaning leaf name: Tropheops_sp._red_cheek -> Tropheops_sp_red_cheek
# Cleaning leaf name: Tropheops_sp._orange_chest -> Tropheops_sp_orange_chest
# Cleaning leaf name: Haplochromis_sp._93/40 -> Haplochromis_sp_93/40
# Cleaning leaf name: Haplochromis_sp._dwarf_big_eye -> Haplochromis_sp_dwarf_big_eye
# Cleaning leaf name: Astatotilapia_sp._Blue_Rufiji -> Astatotilapia_sp_Blue_Rufiji
# Cleaning leaf name: Haplochromis_sp._Lake_Kijanebalola -> Haplochromis_sp_Lake_Kijanebalola
# Cleaning leaf name: Haplochromis_sp._Yaekama -> Haplochromis_sp_Yaekama
# Cleaning leaf name: Haplochromis_sp._Kyoga -> Haplochromis_sp_Kyoga
# Cleaning leaf name: Haplochromis_sp._Lake_Rakai -> Haplochromis_sp_Lake_Rakai
# Cleaning leaf name: Haplochromis_sp._93/8 -> Haplochromis_sp_93/8
# Cleaning leaf name: Astatotilapia_sp._Ruaha -> Astatotilapia_sp_Ruaha
# Cleaning leaf name: Haplochromis_sp._Sanzikwa -> Haplochromis_sp_Sanzikwa
# Cleaning leaf name: Petrochromis_sp._Texas_Longola -> Petrochromis_sp_Texas_Longola
# Cleaning leaf name: Petrochromis_cf._macrognathus_SK-2009 -> Petrochromis_cf_macrognathus_SK-2009
# Cleaning leaf name: Petrochromis_sp._Moshi_yellow -> Petrochromis_sp_Moshi_yellow
# Cleaning leaf name: Petrochromis_sp._Katete -> Petrochromis_sp_Katete
# Cleaning leaf name: Tropheus_sp._Kirschfleck -> Tropheus_sp_Kirschfleck
# Cleaning leaf name: Tropheus_sp._Mpimbwe -> Tropheus_sp_Mpimbwe
# Cleaning leaf name: Tropheus_sp._Bemba -> Tropheus_sp_Bemba
# Cleaning leaf name: Petrochromis_cf._polyodon_SK-2009 -> Petrochromis_cf_polyodon_SK-2009
# Cleaning leaf name: Petrochromis_sp._macrognathus_rainbow -> Petrochromis_sp_macrognathus_rainbow
# Cleaning leaf name: Tropheus_sp._Nakaku -> Tropheus_sp_Nakaku
# Cleaning leaf name: Tropheus_sp._Kapampa -> Tropheus_sp_Kapampa
# Cleaning leaf name: Tropheus_sp._Kachese -> Tropheus_sp_Kachese
# Cleaning leaf name: Orthochromis_aff._kalungwishiensis_H07 -> Orthochromis_aff_kalungwishiensis_H07
# Cleaning leaf name: Serranochromis_sp._black_and_white -> Serranochromis_sp_black_and_white
# Cleaning leaf name: Serranochromis_sp._yellow_fins -> Serranochromis_sp_yellow_fins
# Cleaning leaf name: Haplochromis_sp._Kwango -> Haplochromis_sp_Kwango
# Cleaning leaf name: Haplochromis_cf._bakongo_H38 -> Haplochromis_cf_bakongo_H38
# Cleaning leaf name: Haplochromis_cf._bakongo_H39 -> Haplochromis_cf_bakongo_H39
# Cleaning leaf name: Haplochromis_cf._polli_Lefini -> Haplochromis_cf_polli_Lefini
# Cleaning leaf name: Orthochromis_cf._stormsi_Kisangani -> Orthochromis_cf_stormsi_Kisangani
# Cleaning leaf name: Pharyngochromis_sp._white_tip -> Pharyngochromis_sp_white_tip
# Cleaning leaf name: Pharyngochromis_sp._yellow_lip -> Pharyngochromis_sp_yellow_lip
# Cleaning leaf name: Serranochromis_sp._red_scales -> Serranochromis_sp_red_scales
# Cleaning leaf name: Cyprichromis_sp._zebra -> Cyprichromis_sp_zebra
# Cleaning leaf name: Cyprichromis_sp._jumbo -> Cyprichromis_sp_jumbo
# Cleaning leaf name: Neolamprologus_sp._eseki -> Neolamprologus_sp_eseki
# Cleaning leaf name: Neolamprologus_cf._meeli/boulengeri -> Neolamprologus_cf_meeli/boulengeri
# Cleaning leaf name: Altolamprologus_sp._shell -> Altolamprologus_sp_shell
# Cleaning leaf name: Lamprologus_cf._ocellatus_BN-2009 -> Lamprologus_cf_ocellatus_BN-2009
# Cleaning leaf name: Neolamprologus_sp._Kipili -> Neolamprologus_sp_Kipili
# Cleaning leaf name: Neolamprologus_sp._ndobnoi -> Neolamprologus_sp_ndobnoi
# Cleaning leaf name: Steatocranus_aff._tinanti_Inga -> Steatocranus_aff_tinanti_Inga
# Cleaning leaf name: Steatocranus_aff._tinanti_ultraslender -> Steatocranus_aff_tinanti_ultraslender
# Cleaning leaf name: Steatocranus_aff._tinanti_intermediate -> Steatocranus_aff_tinanti_intermediate
# Cleaning leaf name: Steatocranus_cf._gibbiceps_JS-2011 -> Steatocranus_cf_gibbiceps_JS-2011
# Cleaning leaf name: Steatocranus_sp._Kisangani -> Steatocranus_sp_Kisangani
# Cleaning leaf name: Steatocranus_sp._Nki -> Steatocranus_sp_Nki
# Cleaning leaf name: Steatocranus_sp._Lefini -> Steatocranus_sp_Lefini
# Cleaning leaf name: Steatocranus_aff._casuarius_brown_pearl -> Steatocranus_aff_casuarius_brown_pearl
# Cleaning leaf name: Steatocranus_sp._Maluku -> Steatocranus_sp_Maluku
# Cleaning leaf name: Steatocranus_sp._dwarf -> Steatocranus_sp_dwarf
# Cleaning leaf name: Steatocranus_sp._bulky_head -> Steatocranus_sp_bulky_head
# Cleaning leaf name: Steatocranus_sp._redeye -> Steatocranus_sp_redeye
# Cleaning leaf name: Coptodon_aff._rheophila_Samou -> Coptodon_aff_rheophila_Samou
# Cleaning leaf name: Sarotherodon_aff._galilaeus_mudfeeder -> Sarotherodon_aff_galilaeus_mudfeeder
# Cleaning leaf name: Nanochromis_sp._Ndongo -> Nanochromis_sp_Ndongo
# Cleaning leaf name: Congochromis_cf._sabinae_JS-2011 -> Congochromis_cf_sabinae_JS-2011
# Cleaning leaf name: Congochromis_sp._Amba_River -> Congochromis_sp_Amba_River
# Cleaning leaf name: Paretroplus_cf._kieneri -> Paretroplus_cf_kieneri
# Cleaning leaf name: Bedotia_sp._Ankavia -> Bedotia_sp_Ankavia
# Cleaning leaf name: Bedotia_sp._Namorona -> Bedotia_sp_Namorona
# Cleaning leaf name: Telmatherina_cf._wahjui_ZSM_T53 -> Telmatherina_cf_wahjui_ZSM_T53
# Cleaning leaf name: Tominanga_sp._ZSM_33133 -> Tominanga_sp_ZSM_33133
# Cleaning leaf name: Tominanga_sp._ZSM_33134 -> Tominanga_sp_ZSM_33134
# Cleaning leaf name: Paratherina_cf._striata_ZSM_33057 -> Paratherina_cf_striata_ZSM_33057
# Cleaning leaf name: Paratherina_cf._labiosa_ZSM_33054 -> Paratherina_cf_labiosa_ZSM_33054
# Cleaning leaf name: Telmatherina_cf._obscura_ZSM_33126 -> Telmatherina_cf_obscura_ZSM_33126
# Cleaning leaf name: Melanotaenia_sp._Dekai -> Melanotaenia_sp_Dekai
# Cleaning leaf name: Melanotaenia_cf._eachamensis_ZSM_34158 -> Melanotaenia_cf_eachamensis_ZSM_34158
# Cleaning leaf name: Melanotaenia_sp._Bindoola -> Melanotaenia_sp_Bindoola
# Cleaning leaf name: Chilatherina_sp._ZSM_34143 -> Chilatherina_sp_ZSM_34143
# Cleaning leaf name: Chilatherina_sp._Gidomen -> Chilatherina_sp_Gidomen
# Cleaning leaf name: Melanotaenia_sp._Pianfon -> Melanotaenia_sp_Pianfon
# Cleaning leaf name: Melanotaenia_sp._Rawara -> Melanotaenia_sp_Rawara
# Cleaning leaf name: Melanotaenia_sp._Suswa -> Melanotaenia_sp_Suswa
# Cleaning leaf name: Craterocephalus_sp._ZSM_34172-3 -> Craterocephalus_sp_ZSM_34172-3
# Cleaning leaf name: Craterocephalus_sp._ZSM_34172-1 -> Craterocephalus_sp_ZSM_34172-1
# Cleaning leaf name: Iso_sp._KU_IT_803 -> Iso_sp_KU_IT_803
# Cleaning leaf name: Atherinella_sp._DDB-2013 -> Atherinella_sp_DDB-2013
# Cleaning leaf name: Pseudoxiphophorus_cf._tuxtlaensis_AA-2012 -> Pseudoxiphophorus_cf_tuxtlaensis_AA-2012
# Cleaning leaf name: Poecilia_cf._sphenops_2_FA-2013 -> Poecilia_cf_sphenops_2_FA-2013
# Cleaning leaf name: Poecilia_cf._gillii_1_FA-2013 -> Poecilia_cf_gillii_1_FA-2013
# Cleaning leaf name: Anablepsoides_aff._atratus -> Anablepsoides_aff_atratus
# Cleaning leaf name: Nothobranchius_aff._fasciatus_KEN_08-9 -> Nothobranchius_aff_fasciatus_KEN_08-9
# Cleaning leaf name: Nothobranchius_sp._MZHL_2005-13AG223 -> Nothobranchius_sp_MZHL_2005-13AG223
# Cleaning leaf name: Nothobranchius aff. janpapi JAP_AG205 -> Nothobranchius_aff_janpapi_JAP_AG205
# Cleaning leaf name: Nothobranchius_sp._CI_2007 -> Nothobranchius_sp_CI_2007
# Cleaning leaf name: Nothobranchius_sp._KE_2003-1 -> Nothobranchius_sp_KE_2003-1
# Cleaning leaf name: Acanthemblemaria_sp._RIE-2011 -> Acanthemblemaria_sp_RIE-2011
# Cleaning leaf name: Blenniella_sp._SAIAB_83079-GG07-A081 -> Blenniella_sp_SAIAB_83079-GG07-A081
# Cleaning leaf name: Arcos_sp._KU_149 -> Arcos_sp_KU_149
# Cleaning leaf name: Proterorhinus_sp._CAS-2008 -> Proterorhinus_sp_CAS-2008
# Cleaning leaf name: Proterorhinus_cf._semipellucidus_CAS-2008 -> Proterorhinus_cf_semipellucidus_CAS-2008
# Cleaning leaf name: Rhinogobius_sp._CO -> Rhinogobius_sp_CO
# Cleaning leaf name: Rhinogobius_sp._YB -> Rhinogobius_sp_YB
# Cleaning leaf name: Rhinogobius_sp._DL -> Rhinogobius_sp_DL
# Cleaning leaf name: Rhinogobius_sp._BW -> Rhinogobius_sp_BW
# Cleaning leaf name: Rhinogobius_sp._BF -> Rhinogobius_sp_BF
# Cleaning leaf name: Rhinogobius_sp._OM -> Rhinogobius_sp_OM
# Cleaning leaf name: Rhinogobius_sp._OR -> Rhinogobius_sp_OR
# Cleaning leaf name: Rhinogobius_sp._KZ -> Rhinogobius_sp_KZ
# Cleaning leaf name: Rhinogobius_sp._MO -> Rhinogobius_sp_MO
# Cleaning leaf name: Rhinogobius_sp._BB -> Rhinogobius_sp_BB
# Cleaning leaf name: Rhinogobius_sp._TO -> Rhinogobius_sp_TO
# Cleaning leaf name: Eviota_cf._nebulosa_LT-2014 -> Eviota_cf_nebulosa_LT-2014
# Cleaning leaf name: Eviota_sp._Red_Sea_2 -> Eviota_sp_Red_Sea_2
# Cleaning leaf name: Eviota_cf._fallax_LT-2014 -> Eviota_cf_fallax_LT-2014
# Cleaning leaf name: Eviota_cf._guttata_LT-2012 -> Eviota_cf_guttata_LT-2012
# Cleaning leaf name: Eviota_sp._Red_Sea_1 -> Eviota_sp_Red_Sea_1
# Cleaning leaf name: Eviota_sp._Pohnpei_1 -> Eviota_sp_Pohnpei_1
# Cleaning leaf name: Gobiodon_sp._4_JH-2009 -> Gobiodon_sp_4_JH-2009
# Cleaning leaf name: Gobiodon_sp._D_Munday_1999 -> Gobiodon_sp_D_Munday_1999
# Cleaning leaf name: Gobiodon_sp._A_Munday_1999 -> Gobiodon_sp_A_Munday_1999
# Cleaning leaf name: Gobiodon_sp._B_Munday_1999 -> Gobiodon_sp_B_Munday_1999
# Cleaning leaf name: Gobiodon_sp._C_Munday_1999 -> Gobiodon_sp_C_Munday_1999
# Cleaning leaf name: Eviota_cf._bifasciata_LT-2014 -> Eviota_cf_bifasciata_LT-2014
# Cleaning leaf name: Eviota_cf._spilota_LT-2012 -> Eviota_cf_spilota_LT-2012
# Cleaning leaf name: Eviota_cf._atriventris_LT-2014 -> Eviota_cf_atriventris_LT-2014
# Cleaning leaf name: Eviota_cf._dorsogilva_LT-2014 -> Eviota_cf_dorsogilva_LT-2014
# Cleaning leaf name: Eviota_sp._Red_Sea_3 -> Eviota_sp_Red_Sea_3
# Cleaning leaf name: Eviota_cf._shimadai_LT-2014 -> Eviota_cf_shimadai_LT-2014
# Cleaning leaf name: Eviota_cf._storthynx_LT-2014 -> Eviota_cf_storthynx_LT-2014
# Cleaning leaf name: Eviota_sp._LT-2014b -> Eviota_sp_LT-2014b
# Cleaning leaf name: Luciogobius_sp._TY-2009a -> Luciogobius_sp_TY-2009a
# Cleaning leaf name: Gnatholepis_sp._CT-2003 -> Gnatholepis_sp_CT-2003
# Cleaning leaf name: Sicyopus_sp._41B19B -> Sicyopus_sp_41B19B
# Cleaning leaf name: Siphamia_sp._A73 -> Siphamia_sp_A73
# Cleaning leaf name: Trichiurus_sp._TENJIKUTACHI -> Trichiurus_sp_TENJIKUTACHI
# Cleaning leaf name: Trichiurus_sp._OKINAWA-OOTACHI -> Trichiurus_sp_OKINAWA-OOTACHI
# Cleaning leaf name: Chiasmodon_sp._WLS_1159 -> Chiasmodon_sp_WLS_1159
# Cleaning leaf name: Synchiropus_sp._YFTC_14560 -> Synchiropus_sp_YFTC_14560
# Cleaning leaf name: Upeneus_sp._1_GG-2013 -> Upeneus_sp_1_GG-2013
# Cleaning leaf name: Parupeneus_sp.1 -> Parupeneus_sp1
# Cleaning leaf name: Hippocampus_cf._sindonis -> Hippocampus_cf_sindonis
# Cleaning leaf name: Hippocampus_cf._mohnikei_JS-2021 -> Hippocampus_cf_mohnikei_JS-2021
# Cleaning leaf name: Hippocampus_sp. -> Hippocampus_sp
# Cleaning leaf name: Idiotropiscis_sp._JS-2021 -> Idiotropiscis_sp_JS-2021
# Cleaning leaf name: Aulostomus_sp._CUR14037.G -> Aulostomus_sp_CUR14037G
# Cleaning leaf name: Gyrinomimus_cf._myersi -> Gyrinomimus_cf_myersi
# Cleaning leaf name: Nezumia_cf._africana_ARV-2009 -> Nezumia_cf_africana_ARV-2009
# Cleaning leaf name: Cyttopsis_sp._CUR14111.G -> Cyttopsis_sp_CUR14111G
# Cleaning leaf name: Centrobranchus_cf._brevirostris_AMNH_261206 -> Centrobranchus_cf_brevirostris_AMNH_261206
# Cleaning leaf name: Diogenichthys_sp._AMS_I.45493-004 -> Diogenichthys_sp_AMS_I45493-004
# Cleaning leaf name: Diaphus_sp._YFTC_14535 -> Diaphus_sp_YFTC_14535
# Cleaning leaf name: Sudis_sp._MPD-2008 -> Sudis_sp_MPD-2008
# Cleaning leaf name: Odontostomops_sp._MPD-2008 -> Odontostomops_sp_MPD-2008
# Cleaning leaf name: Scopelarchus_sp._MPD-2008 -> Scopelarchus_sp_MPD-2008
# Cleaning leaf name: Ipnops_sp._MPD-2008 -> Ipnops_sp_MPD-2008
# Cleaning leaf name: Aulopus_sp._MPD-2008 -> Aulopus_sp_MPD-2008
# Cleaning leaf name: Galaxias sp. D (Allibone et al., 1996) -> Galaxias_sp_D_Allibone_et_al_1996
# Cleaning leaf name: Galaxias_sp._southern -> Galaxias_sp_southern
# Cleaning leaf name: Galaxias_sp._northern -> Galaxias_sp_northern
# Cleaning leaf name: Galaxias_sp._teviot -> Galaxias_sp_teviot
# Cleaning leaf name: Galaxias_sp._Hunter -> Galaxias_sp_Hunter
# Cleaning leaf name: Brachyhypopomus_sp._PAL -> Brachyhypopomus_sp_PAL
# Cleaning leaf name: Gymnotus_sp. -> Gymnotus_sp
# Cleaning leaf name: Gymnotus_cf._anguillaris_NRL-2009 -> Gymnotus_cf_anguillaris_NRL-2009
# Cleaning leaf name: Gymnotus_cf._maculosus -> Gymnotus_cf_maculosus
# Cleaning leaf name: Eigenmannia_cf._virescens -> Eigenmannia_cf_virescens
# Cleaning leaf name: Notarius_aff._kessleri_RB-2009 -> Notarius_aff_kessleri_RB-2009
# Cleaning leaf name: Notarius_aff._planiceps_RB-2004 -> Notarius_aff_planiceps_RB-2004
# Cleaning leaf name: Cathorops_aff._fuerthii_STRI-5726 -> Cathorops_aff_fuerthii_STRI-5726
# Cleaning leaf name: Cathorops_cf._higuchii_RB-2009 -> Cathorops_cf_higuchii_RB-2009
# Cleaning leaf name: Cathorops_cf._festae_RB-2009 -> Cathorops_cf_festae_RB-2009
# Cleaning leaf name: Bagre_aff._marinus_RB-2012 -> Bagre_aff_marinus_RB-2012
# Cleaning leaf name: Bagre_aff._marinus_INVEMAR-PEC_5336 -> Bagre_aff_marinus_INVEMAR-PEC_5336
# Cleaning leaf name: Arius_aff._sp._A_RB-2009 -> Arius_aff_sp_A_RB-2009
# Cleaning leaf name: Arius_sp._A_RB-2009 -> Arius_sp_A_RB-2009
# Cleaning leaf name: Nemapteryx_aff._nenga_RB-2009 -> Nemapteryx_aff_nenga_RB-2009
# Cleaning leaf name: Neoarius_aff._leptaspis_RB-2009 -> Neoarius_aff_leptaspis_RB-2009
# Cleaning leaf name: Neoarius_aff._graeffei_1_RB-2009 -> Neoarius_aff_graeffei_1_RB-2009
# Cleaning leaf name: Neoarius_aff._graeffei_2_RB-2009 -> Neoarius_aff_graeffei_2_RB-2009
# Cleaning leaf name: Nemapteryx_aff._armiger_RB-2009 -> Nemapteryx_aff_armiger_RB-2009
# Cleaning leaf name: Plicofollis_aff._layardi_RB-2009 -> Plicofollis_aff_layardi_RB-2009
# Cleaning leaf name: Plicofollis_aff._argyropleuron_2_RB-2009 -> Plicofollis_aff_argyropleuron_2_RB-2009
# Cleaning leaf name: Plicofollis_cf._polystaphylodon_RB-2009 -> Plicofollis_cf_polystaphylodon_RB-2009
# Cleaning leaf name: Plicofollis_aff._polystaphylodon_RB-2009 -> Plicofollis_aff_polystaphylodon_RB-2009
# Cleaning leaf name: Plicofollis_aff._argyropleuron_1_RB-2009 -> Plicofollis_aff_argyropleuron_1_RB-2009
# Cleaning leaf name: Netuma_aff._thalassina_RB-2009 -> Netuma_aff_thalassina_RB-2009
# Cleaning leaf name: Netuma_aff._bilineata_RB-2009 -> Netuma_aff_bilineata_RB-2009
# Cleaning leaf name: Ariopsis_sp._RB-2009 -> Ariopsis_sp_RB-2009
# Cleaning leaf name: Galeichthys_sp._RB-2012 -> Galeichthys_sp_RB-2012
# Cleaning leaf name: Noturus_sp._broadtail-INHS90217 -> Noturus_sp_broadtail-INHS90217
# Cleaning leaf name: Phyllonemus_sp._C_CP-2014 -> Phyllonemus_sp_C_CP-2014
# Cleaning leaf name: Phyllonemus_sp._D_CP-2014 -> Phyllonemus_sp_D_CP-2014
# Cleaning leaf name: Phyllonemus_sp._B_CP-2014 -> Phyllonemus_sp_B_CP-2014
# Cleaning leaf name: Phyllonemus_sp._A_CP-2014 -> Phyllonemus_sp_A_CP-2014
# Cleaning leaf name: Phyllonemus_aff._brichardi_CP-2014 -> Phyllonemus_aff_brichardi_CP-2014
# Cleaning leaf name: Chrysichthys_cf._grandis_CP-2014 -> Chrysichthys_cf_grandis_CP-2014
# Cleaning leaf name: Chrysichthys_sp._1_CP-2014 -> Chrysichthys_sp_1_CP-2014
# Cleaning leaf name: Chrysichthys_sp._2_CP-2014 -> Chrysichthys_sp_2_CP-2014
# Cleaning leaf name: Chrysichthys_sp._3_CP-2014 -> Chrysichthys_sp_3_CP-2014
# Cleaning leaf name: Chrysichthys_sp._4_CP-2014 -> Chrysichthys_sp_4_CP-2014
# Cleaning leaf name: Synodontis_aff._thamalakalensis_SAIAB_52277 -> Synodontis_aff_thamalakalensis_SAIAB_52277
# Cleaning leaf name: Synodontis_sp._CU_91588 -> Synodontis_sp_CU_91588
# Cleaning leaf name: Synodontis_sp._CU_91594 -> Synodontis_sp_CU_91594
# Cleaning leaf name: Synodontis_aff._afrofischeri_CU_90419 -> Synodontis_aff_afrofischeri_CU_90419
# Cleaning leaf name: Synodontis_sp._CU_94803 -> Synodontis_sp_CU_94803
# Cleaning leaf name: Synodontis_aff._laessoei_SAIAB_85182 -> Synodontis_aff_laessoei_SAIAB_85182
# Cleaning leaf name: Synodontis_cf._obesus_W080 -> Synodontis_cf_obesus_W080
# Cleaning leaf name: Synodontis_aff._petricola_JJD-2006 -> Synodontis_aff_petricola_JJD-2006
# Cleaning leaf name: Synodontis_aff._ilebrevis_BMNH_2006.3.6.25 -> Synodontis_aff_ilebrevis_BMNH_20063625
# Cleaning leaf name: Synodontis_aff._tanganyicae_CU_88758 -> Synodontis_aff_tanganyicae_CU_88758
# Cleaning leaf name: Synodontis_sp._SAIAB_73898 -> Synodontis_sp_SAIAB_73898
# Cleaning leaf name: Synodontis_sp._ngamensis -> Synodontis_sp_ngamensis
# Cleaning leaf name: Synodontis_aff._punctulata_BMNH_2007.8.29.25 -> Synodontis_aff_punctulata_BMNH_200782925
# Cleaning leaf name: Synodontis_aff._schall_A042 -> Synodontis_aff_schall_A042
# Cleaning leaf name: Microsynodontis_sp._CU_89213 -> Microsynodontis_sp_CU_89213
# Cleaning leaf name: Amphilius_cf._jacksonii_CU_90426 -> Amphilius_cf_jacksonii_CU_90426
# Cleaning leaf name: Clarias_sp._maurus -> Clarias_sp_maurus
# Cleaning leaf name: Microglanis_aff._cottoides_LBP731 -> Microglanis_aff_cottoides_LBP731
# Cleaning leaf name: Batrochoglanis_aff._villosus_LBP2347 -> Batrochoglanis_aff_villosus_LBP2347
# Cleaning leaf name: Hemibagrus_sp._C_JJD-2014 -> Hemibagrus_sp_C_JJD-2014
# Cleaning leaf name: Hemibagrus_sp._B_JJD-2014 -> Hemibagrus_sp_B_JJD-2014
# Cleaning leaf name: Glyptothorax_sp._Nujiang_WSJ-2010 -> Glyptothorax_sp_Nujiang_WSJ-2010
# Cleaning leaf name: Glyptothorax_cf._trilineatus_INHS_93545 -> Glyptothorax_cf_trilineatus_INHS_93545
# Cleaning leaf name: Glyptothorax_sp._Cangyuan_WSJ-2010 -> Glyptothorax_sp_Cangyuan_WSJ-2010
# Cleaning leaf name: Pimelodus_cf._altissimus_JPS-2012 -> Pimelodus_cf_altissimus_JPS-2012
# Cleaning leaf name: Hypophthalmus_cf._marginatus_JPS-2012 -> Hypophthalmus_cf_marginatus_JPS-2012
# Cleaning leaf name: Hypophthalmus_cf._edentatus_JPS-2012 -> Hypophthalmus_cf_edentatus_JPS-2012
# Cleaning leaf name: Rhamdia_aff._rogersi -> Rhamdia_aff_rogersi
# Cleaning leaf name: Rhamdia_aff._cabrerae -> Rhamdia_aff_cabrerae
# Cleaning leaf name: Myoglanis_sp._ANSP_182834 -> Myoglanis_sp_ANSP_182834
# Cleaning leaf name: Imparfinis_cf._cochabambae_ANSP_180641 -> Imparfinis_cf_cochabambae_ANSP_180641
# Cleaning leaf name: Imparfinis_cf._stictonotus_ANSP_179440 -> Imparfinis_cf_stictonotus_ANSP_179440
# Cleaning leaf name: Phreatobius_sp._INPA_S/N -> Phreatobius_sp_INPA_S/N
# Cleaning leaf name: Leptodoras_cf._praelongus -> Leptodoras_cf_praelongus
# Cleaning leaf name: Trachydoras_cf._microstomus -> Trachydoras_cf_microstomus
# Cleaning leaf name: Centrodoras_cf._brachiatus -> Centrodoras_cf_brachiatus
# Cleaning leaf name: Amblydoras_cf._affinis -> Amblydoras_cf_affinis
# Cleaning leaf name: Amblydoras_cf._monitor -> Amblydoras_cf_monitor
# Cleaning leaf name: Astroblepus_sp._1-Panama -> Astroblepus_sp_1-Panama
# Cleaning leaf name: Astroblepus_sp._2-Peru -> Astroblepus_sp_2-Peru
# Cleaning leaf name: Astroblepus_sp._LBP1357 -> Astroblepus_sp_LBP1357
# Cleaning leaf name: Astroblepus_sp._2-Ecuador -> Astroblepus_sp_2-Ecuador
# Cleaning leaf name: Pterygoplichthys_sp._LBP3252-18042 -> Pterygoplichthys_sp_LBP3252-18042
# Cleaning leaf name: Peckoltia_cf._vittata_GSCS-2015 -> Peckoltia_cf_vittata_GSCS-2015
# Cleaning leaf name: Peckoltia_sp._LBP1610-11673 -> Peckoltia_sp_LBP1610-11673
# Cleaning leaf name: Peckoltia_sp._LBP4953-11491 -> Peckoltia_sp_LBP4953-11491
# Cleaning leaf name: Panaqolus_cf._maccus_GSCS-2015 -> Panaqolus_cf_maccus_GSCS-2015
# Cleaning leaf name: Panaqolus_sp._L271 -> Panaqolus_sp_L271
# Cleaning leaf name: Hypancistrus_sp._L333 -> Hypancistrus_sp_L333
# Cleaning leaf name: Hypancistrus_sp._L316 -> Hypancistrus_sp_L316
# Cleaning leaf name: Hypancistrus_sp._L260 -> Hypancistrus_sp_L260
# Cleaning leaf name: Pseudacanthicus_sp._L025 -> Pseudacanthicus_sp_L025
# Cleaning leaf name: Pseudacanthicus_sp._L185 -> Pseudacanthicus_sp_L185
# Cleaning leaf name: Pseudacanthicus_sp._L273 -> Pseudacanthicus_sp_L273
# Cleaning leaf name: Leporacanthicus_sp._L263 -> Leporacanthicus_sp_L263
# Cleaning leaf name: Pseudancistrus_sp._L17 -> Pseudancistrus_sp_L17
# Cleaning leaf name: Pseudolithoxus_cf._kelsorum_RC-2012 -> Pseudolithoxus_cf_kelsorum_RC-2012
# Cleaning leaf name: Pseudolithoxus_sp._INPA_43888 -> Pseudolithoxus_sp_INPA_43888
# Cleaning leaf name: Ancistrus_sp._11_GSCS-2015 -> Ancistrus_sp_11_GSCS-2015
# Cleaning leaf name: Ancistrus_sp._10_GSCS-2015 -> Ancistrus_sp_10_GSCS-2015
# Cleaning leaf name: Ancistrus_sp._2_GSCS-2015 -> Ancistrus_sp_2_GSCS-2015
# Cleaning leaf name: Ancistrus_sp._1_GSCS-2015 -> Ancistrus_sp_1_GSCS-2015
# Cleaning leaf name: Ancistrus_sp._3_GSCS-2015 -> Ancistrus_sp_3_GSCS-2015
# Cleaning leaf name: Ancistrus_sp._4_GSCS-2015 -> Ancistrus_sp_4_GSCS-2015
# Cleaning leaf name: Ancistrus_sp._6_GSCS-2015 -> Ancistrus_sp_6_GSCS-2015
# Cleaning leaf name: Ancistrus_sp._7_GSCS-2015 -> Ancistrus_sp_7_GSCS-2015
# Cleaning leaf name: Ancistrus_sp._5_GSCS-2015 -> Ancistrus_sp_5_GSCS-2015
# Cleaning leaf name: Ancistrus_sp._8_GSCS-2015 -> Ancistrus_sp_8_GSCS-2015
# Cleaning leaf name: Ancistrus_sp._9_GSCS-2015 -> Ancistrus_sp_9_GSCS-2015
# Cleaning leaf name: Ancistrus_sp._Inambari -> Ancistrus_sp_Inambari
# Cleaning leaf name: Ancistrus_sp._Xingu -> Ancistrus_sp_Xingu
# Cleaning leaf name: Lasiancistrus_sp._LBP14817-57761 -> Lasiancistrus_sp_LBP14817-57761
# Cleaning leaf name: Panaque_sp._L204 -> Panaque_sp_L204
# Cleaning leaf name: Chaetostoma_cf._changae_GSCS-2015 -> Chaetostoma_cf_changae_GSCS-2015
# Cleaning leaf name: Parotocinclus_sp._LBP6950-35328 -> Parotocinclus_sp_LBP6950-35328
# Cleaning leaf name: Rhinolekos_sp._LBP5848_28365 -> Rhinolekos_sp_LBP5848_28365
# Cleaning leaf name: Hisonotus cf. paulinus BOLD:AAC1623 -> Hisonotus_cf_paulinus_BOLDAAC1623
# Cleaning leaf name: Hisonotus_sp._LBP334_4276 -> Hisonotus_sp_LBP334_4276
# Cleaning leaf name: Hisonotus_sp._LBP8276_38487 -> Hisonotus_sp_LBP8276_38487
# Cleaning leaf name: Parotocinclus_aff._spilurus_LBP5624_35326 -> Parotocinclus_aff_spilurus_LBP5624_35326
# Cleaning leaf name: Parotocinclus_aff._spilurus_LBP5624_35327 -> Parotocinclus_aff_spilurus_LBP5624_35327
# Cleaning leaf name: Corumbataia_sp._c_FR-2018 -> Corumbataia_sp_c_FR-2018
# Cleaning leaf name: Corumbataia_sp._a_FR-2018 -> Corumbataia_sp_a_FR-2018
# Cleaning leaf name: Neoplecostomus_sp._3_FFR-2012 -> Neoplecostomus_sp_3_FFR-2012
# Cleaning leaf name: Neoplecostomus_sp._4_FFR-2012 -> Neoplecostomus_sp_4_FFR-2012
# Cleaning leaf name: Neoplecostomus_sp._5_FFR-2012 -> Neoplecostomus_sp_5_FFR-2012
# Cleaning leaf name: Neoplecostomus_sp._6_FFR-2012 -> Neoplecostomus_sp_6_FFR-2012
# Cleaning leaf name: Neoplecostomus_sp._7_FFR-2012 -> Neoplecostomus_sp_7_FFR-2012
# Cleaning leaf name: Neoplecostomus_sp._9_FFR-2012 -> Neoplecostomus_sp_9_FFR-2012
# Cleaning leaf name: Neoplecostomus_sp._8_FFR-2012 -> Neoplecostomus_sp_8_FFR-2012
# Cleaning leaf name: Neoplecostomus_sp._1_FFR-2012 -> Neoplecostomus_sp_1_FFR-2012
# Cleaning leaf name: Neoplecostomus_sp._2_FFR-2012 -> Neoplecostomus_sp_2_FFR-2012
# Cleaning leaf name: Neoplecostomus_cf._botucatu_LBP709-6049 -> Neoplecostomus_cf_botucatu_LBP709-6049
# Cleaning leaf name: Pareiorhina_cf._carrancas_LBP1087-10256 -> Pareiorhina_cf_carrancas_LBP1087-10256
# Cleaning leaf name: Pareiorhina_sp._1_FFR-2012 -> Pareiorhina_sp_1_FFR-2012
# Cleaning leaf name: Kronichthys_sp._1_FFR-2012 -> Kronichthys_sp_1_FFR-2012
# Cleaning leaf name: Isbrueckerichthys_sp._1_FFR-2012 -> Isbrueckerichthys_sp_1_FFR-2012
# Cleaning leaf name: Isbrueckerichthys_cf._calvus_LBP6389_29765 -> Isbrueckerichthys_cf_calvus_LBP6389_29765
# Cleaning leaf name: Pareiorhina_cf._rudolphi_LBP4391-24189 -> Pareiorhina_cf_rudolphi_LBP4391-24189
# Cleaning leaf name: Oxyropsis_sp._LBP6973_35324 -> Oxyropsis_sp_LBP6973_35324
# Cleaning leaf name: Acestridium_sp._LBP7204_35332 -> Acestridium_sp_LBP7204_35332
# Cleaning leaf name: Rineloricaria_aff._heteroptera_LBP1731_12865 -> Rineloricaria_aff_heteroptera_LBP1731_12865
# Cleaning leaf name: Pseudancistrus_sp._Nassau -> Pseudancistrus_sp_Nassau
# Cleaning leaf name: Corydoras_cf._punctatus_MA350 -> Corydoras_cf_punctatus_MA350
# Cleaning leaf name: Corydoras_cf._guianensis_MA102 -> Corydoras_cf_guianensis_MA102
# Cleaning leaf name: Corydoras_cf._sipalwini_MA224 -> Corydoras_cf_sipalwini_MA224
# Cleaning leaf name: Corydoras_cf._melini_MA333 -> Corydoras_cf_melini_MA333
# Cleaning leaf name: Corydoras_cf._concolor_MT102 -> Corydoras_cf_concolor_MT102
# Cleaning leaf name: Corydoras_cf._davidsandsi_MA134 -> Corydoras_cf_davidsandsi_MA134
# Cleaning leaf name: Corydoras_cf._pulcher_MT9 -> Corydoras_cf_pulcher_MT9
# Cleaning leaf name: Corydoras_cf._ephippifer_MA336 -> Corydoras_cf_ephippifer_MA336
# Cleaning leaf name: Aspidoras_cf._fuscoguttatus -> Aspidoras_cf_fuscoguttatus
# Cleaning leaf name: Aspidoras_cf._poecilus_MA96 -> Aspidoras_cf_poecilus_MA96
# Cleaning leaf name: Scleromystax_cf._prionotus_MT169 -> Scleromystax_cf_prionotus_MT169
# Cleaning leaf name: Corydoras_cf._hastatus_MT104 -> Corydoras_cf_hastatus_MT104
# Cleaning leaf name: Corydoras_cf._napoensis_MT105 -> Corydoras_cf_napoensis_MT105
# Cleaning leaf name: Corydoras_cf._nijsseni_MT107 -> Corydoras_cf_nijsseni_MT107
# Cleaning leaf name: Corydoras_cf._elegans_MA235 -> Corydoras_cf_elegans_MA235
# Cleaning leaf name: Corydoras_cf._maculifer_MA40 -> Corydoras_cf_maculifer_MA40
# Cleaning leaf name: Corydoras_cf._oxyrhynchus_MA276 -> Corydoras_cf_oxyrhynchus_MA276
# Cleaning leaf name: Corydoras_cf._geoffroy_MA255 -> Corydoras_cf_geoffroy_MA255
# Cleaning leaf name: Corydoras_cf._ellisae_MA37 -> Corydoras_cf_ellisae_MA37
# Cleaning leaf name: Corydoras_cf._pastazensis_MA299 -> Corydoras_cf_pastazensis_MA299
# Cleaning leaf name: Brycon_aff._atrocaudatus_KTA-2014 -> Brycon_aff_atrocaudatus_KTA-2014
# Cleaning leaf name: Salminus_sp. -> Salminus_sp
# Cleaning leaf name: Brycon_cf._falcatus_KTA-2014 -> Brycon_cf_falcatus_KTA-2014
# Cleaning leaf name: Tetragonopterus_sp._Sao_Francisco -> Tetragonopterus_sp_Sao_Francisco
# Cleaning leaf name: Tetragonopterus_sp._Tapajos -> Tetragonopterus_sp_Tapajos
# Cleaning leaf name: Tetragonopterus_sp._Xingu -> Tetragonopterus_sp_Xingu
# Cleaning leaf name: Myloplus_cf._torquatus_ROM_t26429 -> Myloplus_cf_torquatus_ROM_t26429
# Cleaning leaf name: Myloplus_sp._4 -> Myloplus_sp_4
# Cleaning leaf name: Tometes_sp._246 -> Tometes_sp_246
# Cleaning leaf name: Myleus_cf._knerii_ROM_86416 -> Myleus_cf_knerii_ROM_86416
# Cleaning leaf name: Tometes_sp._7022 -> Tometes_sp_7022
# Cleaning leaf name: Myloplus_sp._11 -> Myloplus_sp_11
# Cleaning leaf name: Serrasalmus_sp._1 -> Serrasalmus_sp_1
# Cleaning leaf name: Serrasalmus_cf._gibbus_ROM_MK-18-015 -> Serrasalmus_cf_gibbus_ROM_MK-18-015
# Cleaning leaf name: Serrasalmus_sp._19 -> Serrasalmus_sp_19
# Cleaning leaf name: Metynnis_cf._luna_ROM_t06560 -> Metynnis_cf_luna_ROM_t06560
# Cleaning leaf name: Metynnis_cf._longipinnis_UMMZ_250564 -> Metynnis_cf_longipinnis_UMMZ_250564
# Cleaning leaf name: Metynnis_cf._argenteus_ROM_86134 -> Metynnis_cf_argenteus_ROM_86134
# Cleaning leaf name: Brycon_sp. -> Brycon_sp
# Cleaning leaf name: Niwaella_cf._laterimaculata_IHCAS0000009 -> Niwaella_cf_laterimaculata_IHCAS0000009
# Cleaning leaf name: Cobitis_melanoleuca_cf._sibirica -> Cobitis_melanoleuca_cf_sibirica
# Cleaning leaf name: Pangio_sp._A_VS-2008 -> Pangio_sp_A_VS-2008
# Cleaning leaf name: Pangio_cf._piperata_I_VS-2008 -> Pangio_cf_piperata_I_VS-2008
# Cleaning leaf name: Pangio_cf._piperata_II_VS-2008 -> Pangio_cf_piperata_II_VS-2008
# Cleaning leaf name: Pangio_sp._B_VS-2008 -> Pangio_sp_B_VS-2008
# Cleaning leaf name: Pangio_cf._kuhlii/semicincta_II_VS-2008 -> Pangio_cf_kuhlii/semicincta_II_VS-2008
# Cleaning leaf name: Pangio_cf._kuhlii/semicincta_I_VS-2008 -> Pangio_cf_kuhlii/semicincta_I_VS-2008
# Cleaning leaf name: Pangio_cf._kuhlii/semicincta_VS-2008 -> Pangio_cf_kuhlii/semicincta_VS-2008
# Cleaning leaf name: Pangio_cf._oblonga/malayana_VS-2008 -> Pangio_cf_oblonga/malayana_VS-2008
# Cleaning leaf name: Pangio_cf._pangia_I_VS-2008 -> Pangio_cf_pangia_I_VS-2008
# Cleaning leaf name: Pangio_cf._apoda_I_VS-2008 -> Pangio_cf_apoda_I_VS-2008
# Cleaning leaf name: Pangio_cf._pangia_II_VS-2008 -> Pangio_cf_pangia_II_VS-2008
# Cleaning leaf name: Pangio_cf._apoda_II_VS-2008 -> Pangio_cf_apoda_II_VS-2008
# Cleaning leaf name: Pangio_cf._oblonga_I_VS-2008 -> Pangio_cf_oblonga_I_VS-2008
# Cleaning leaf name: Pangio_cf._oblonga_III_VS-2008 -> Pangio_cf_oblonga_III_VS-2008
# Cleaning leaf name: Pangio_cf._oblonga_II_VS-2008 -> Pangio_cf_oblonga_II_VS-2008
# Cleaning leaf name: Pangio_cf._oblonga_IV_VS-2008 -> Pangio_cf_oblonga_IV_VS-2008
# Cleaning leaf name: Homatula_sp._2_RM-2010 -> Homatula_sp_2_RM-2010
# Cleaning leaf name: Lefua sp. (sensu Hosoya 1993) -> Lefua_sp_sensu_Hosoya_1993
# Cleaning leaf name: Moxostoma_cf._albidum_MDC-2011 -> Moxostoma_cf_albidum_MDC-2011
# Cleaning leaf name: Moxostoma_cf._austrinum_MDC-2011 -> Moxostoma_cf_austrinum_MDC-2011
# Cleaning leaf name: Capoeta_cf._banarescui_SP-2011 -> Capoeta_cf_banarescui_SP-2011
# Cleaning leaf name: Capoeta_cf._saadii_SP-2009 -> Capoeta_cf_saadii_SP-2009
# Cleaning leaf name: Capoeta_sp._2_SP-2011 -> Capoeta_sp_2_SP-2011
# Cleaning leaf name: Percocypris_sp._MW-2013b -> Percocypris_sp_MW-2013b
# Cleaning leaf name: Danionella_sp._South_Myanmar -> Danionella_sp_South_Myanmar
# Cleaning leaf name: Danionella_sp._Jorai_River -> Danionella_sp_Jorai_River
# Cleaning leaf name: Danio_aff._albolineatus -> Danio_aff_albolineatus
# Cleaning leaf name: Boraras_cf._micros_0089 -> Boraras_cf_micros_0089
# Cleaning leaf name: Esomus_cf._ahli_CTOL01578 -> Esomus_cf_ahli_CTOL01578
# Cleaning leaf name: Leptocypris_sp._CTOL03178 -> Leptocypris_sp_CTOL03178
# Cleaning leaf name: Barilius_cf._barila_CTOL02812 -> Barilius_cf_barila_CTOL02812
# Cleaning leaf name: Raiamas_sp._Myanmar -> Raiamas_sp_Myanmar
# Cleaning leaf name: Paedocypris_sp._Banka -> Paedocypris_sp_Banka
# Cleaning leaf name: Paedocypris_sp._Kalimantan -> Paedocypris_sp_Kalimantan
# Cleaning leaf name: Hybopsis_cf._winchelli -> Hybopsis_cf_winchelli
# Cleaning leaf name: Nocomis_cf._leptocephalus_Western_Gulf_Slope -> Nocomis_cf_leptocephalus_Western_Gulf_Slope
# Cleaning leaf name: Pseudophoxinus_sp._Gogdeli_Hot_Springs -> Pseudophoxinus_sp_Gogdeli_Hot_Springs
# Cleaning leaf name: Leuciscus_cf._latus_SP-2010 -> Leuciscus_cf_latus_SP-2010
# Cleaning leaf name: Pseudorasbora_cf._parva -> Pseudorasbora_cf_parva
# Cleaning leaf name: Pseudorasbora_sp._SPH-2006 -> Pseudorasbora_sp_SPH-2006
# Cleaning leaf name: Barbus_sp._Lango -> Barbus_sp_Lango
# Cleaning leaf name: Barbus_cf._pleurogramma_CTOL00033 -> Barbus_cf_pleurogramma_CTOL00033
# Cleaning leaf name: Psilorhynchus_sp._A854 -> Psilorhynchus_sp_A854
# Cleaning leaf name: Psilorhynchus_sp._A855 -> Psilorhynchus_sp_A855
# Cleaning leaf name: Barbus_sp._MNCN141AL -> Barbus_sp_MNCN141AL
# Cleaning leaf name: Enteromius_cf._guirali_LY1096 -> Enteromius_cf_guirali_LY1096
# Cleaning leaf name: Barbus_sp._SPH-2006 -> Barbus_sp_SPH-2006
# Cleaning leaf name: Chirocentrus_sp. -> Chirocentrus_sp
# Cleaning leaf name: Clupeoides_sp._Chao_Phraya -> Clupeoides_sp_Chao_Phraya
# Cleaning leaf name: Sundasalanx_sp._Chao_Phraya -> Sundasalanx_sp_Chao_Phraya
# Cleaning leaf name: Paramormyrops_sp._MAG -> Paramormyrops_sp_MAG

# %%
# Lookups. Try to look up each genus in the taxonomy database.
import re

leaves_sorted_by_order = {}
for leaf in species_tree.get_leaves():
    # Grab the first part of the name. It can be the first word separated by a space,
    # underscore, or dash.
    genus_name = re.split(r'[ _-]', leaf.name)[0]

    # Get the order name from the genus name.
    order_name, family = db.get_species_info(genus_name)

    # Add the order and family to each leaf.
    leaf.add_feature('order', order_name)
    leaf.add_feature('family', family)

    # Make a list of all the insect orders in the tree.
    if order_name not in leaves_sorted_by_order:
        leaves_sorted_by_order[order_name] = []
        print(f"Adding new order: {order_name}")
    leaves_sorted_by_order[order_name].append(leaf)
# Out:
# Cache hit for genus 'Lepisosteus': Order: Lepisosteiformes, Family: Lepisosteidae
# Adding new order: Lepisosteiformes
# Cache hit for genus 'Lepisosteus': Order: Lepisosteiformes, Family: Lepisosteidae
# Cache hit for genus 'Lepisosteus': Order: Lepisosteiformes, Family: Lepisosteidae
# Cache hit for genus 'Lepisosteus': Order: Lepisosteiformes, Family: Lepisosteidae
# Cache hit for genus 'Atractosteus': Order: Lepisosteiformes, Family: Lepisosteidae
# Cache hit for genus 'Atractosteus': Order: Lepisosteiformes, Family: Lepisosteidae
# Cache hit for genus 'Atractosteus': Order: Lepisosteiformes, Family: Lepisosteidae
# Cache hit for genus 'Amia': Order: Amiiformes, Family: Amiidae
# Adding new order: Amiiformes
# Cache hit for genus 'Lepidogalaxias': Order: Osmeriformes, Family: Lepidogalaxiidae
# Adding new order: Osmeriformes
# Cache hit for genus 'Microstoma': Order: Osmeriformes, Family: Microstomatidae
# Cache hit for genus 'Bathylagus': Order: Osmeriformes, Family: Bathylagidae
# Cache hit for genus 'Pseudobathylagus': Order: Osmeriformes, Family: Bathylagidae
# Cache hit for genus 'Bathylagus': Order: Osmeriformes, Family: Bathylagidae
# Cache hit for genus 'Bathylagus': Order: Osmeriformes, Family: Bathylagidae
# Cache hit for genus 'Bathylagus': Order: Osmeriformes, Family: Bathylagidae
# Cache hit for genus 'Leuroglossus': Order: Osmeriformes, Family: Bathylagidae
# Cache hit for genus 'Bathylagoides': Order: Osmeriformes, Family: Bathylagidae
# Cache hit for genus 'Lipolagus': Order: Osmeriformes, Family: Bathylagidae
# Cache hit for genus 'Dolicholagus': Order: Osmeriformes, Family: Bathylagidae
# Cache hit for genus 'Macropinna': Order: Osmeriformes, Family: Opisthoproctidae
# Cache hit for genus 'Rhynchohyalus': Order: Osmeriformes, Family: Opisthoproctidae
# Cache hit for genus 'Argentina': Order: Argentiniformes, Family: Argentinidae
# Adding new order: Argentiniformes
# Cache hit for genus 'Argentina': Order: Argentiniformes, Family: Argentinidae
# Cache hit for genus 'Argentina': Order: Argentiniformes, Family: Argentinidae
# Cache hit for genus 'Argentina': Order: Argentiniformes, Family: Argentinidae
# Cache hit for genus 'Nansenia': Order: Argentiniformes, Family: Microstomatidae
# Cache hit for genus 'Nansenia': Order: Argentiniformes, Family: Microstomatidae
# Cache hit for genus 'Nansenia': Order: Argentiniformes, Family: Microstomatidae
# Cache hit for genus 'Nansenia': Order: Argentiniformes, Family: Microstomatidae
# Cache hit for genus 'Umbra': Order: Esociformes, Family: Umbridae
# Adding new order: Esociformes
# Cache hit for genus 'Umbra': Order: Esociformes, Family: Umbridae
# Cache hit for genus 'Umbra': Order: Esociformes, Family: Umbridae
# Cache hit for genus 'Esox': Order: Esociformes, Family: Esocidae
# Cache hit for genus 'Esox': Order: Esociformes, Family: Esocidae
# Cache hit for genus 'Esox': Order: Esociformes, Family: Esocidae
# Cache hit for genus 'Esox': Order: Esociformes, Family: Esocidae
# Cache hit for genus 'Esox': Order: Esociformes, Family: Esocidae
# Cache hit for genus 'Esox': Order: Esociformes, Family: Esocidae
# Cache hit for genus 'Esox': Order: Esociformes, Family: Esocidae
# Cache hit for genus 'Novumbra': Order: Esociformes, Family: Umbridae
# Cache hit for genus 'Dallia': Order: Esociformes, Family: Umbridae
# Cache hit for genus 'Oncorhynchus': Order: Salmoniformes, Family: Salmonidae
# Adding new order: Salmoniformes
# Cache hit for genus 'Oncorhynchus': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Oncorhynchus': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Oncorhynchus': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Oncorhynchus': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Oncorhynchus': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Oncorhynchus': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Oncorhynchus': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Oncorhynchus': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Oncorhynchus': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Salvelinus': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Salvelinus': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Salvelinus': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Salvelinus': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Salvelinus': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Salvelinus': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Salvelinus': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Salvelinus': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Salvelinus': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Salvelinus': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Salvelinus': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Salvelinus': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Salvelinus': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Salvelinus': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Salvelinus': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Salvethymus': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Salvelinus': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Salvelinus': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Parahucho': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Salmo': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Salmo': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Salmo': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Salmo': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Salmo': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Salmo': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Salmo': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Salmo': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Salmo': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Salmo': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Salvelinus': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Salvelinus': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Brachymystax': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Brachymystax': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Brachymystax': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Hucho': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Hucho': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Hucho': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Thymallus': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Thymallus': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Thymallus': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Thymallus': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Thymallus': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Thymallus': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Thymallus': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Thymallus': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Coregonus': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Coregonus': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Coregonus': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Coregonus': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Coregonus': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Coregonus': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Coregonus': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Coregonus': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Coregonus': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Coregonus': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Coregonus': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Coregonus': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Coregonus': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Coregonus': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Coregonus': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Coregonus': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Coregonus': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Coregonus': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Coregonus': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Coregonus': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Coregonus': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Coregonus': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Coregonus': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Coregonus': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Coregonus': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Stenodus': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Coregonus': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Coregonus': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Prosopium': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Prosopium': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Prosopium': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Prosopium': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Prosopium': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Prosopium': Order: Salmoniformes, Family: Salmonidae
# Cache hit for genus 'Lampris': Order: Lampriformes, Family: Lampridae
# Adding new order: Lampriformes
# Cache hit for genus 'Lampris': Order: Lampriformes, Family: Lampridae
# Cache hit for genus 'Metavelifer': Order: Lampriformes, Family: Veliferidae
# Cache hit for genus 'Velifer': Order: Lampriformes, Family: Veliferidae
# Cache hit for genus 'Regalecus': Order: Lampriformes, Family: Regalecidae
# Cache hit for genus 'Regalecus': Order: Lampriformes, Family: Regalecidae
# Cache hit for genus 'Desmodema': Order: Lampriformes, Family: Trachipteridae
# Cache hit for genus 'Trachipterus': Order: Lampriformes, Family: Trachipteridae
# Cache hit for genus 'Trachipterus': Order: Lampriformes, Family: Trachipteridae
# Cache hit for genus 'Trachipterus': Order: Lampriformes, Family: Trachipteridae
# Cache hit for genus 'Trachipterus': Order: Lampriformes, Family: Trachipteridae
# Cache hit for genus 'Zu': Order: Lampriformes, Family: Trachipteridae
# Cache hit for genus 'Zu': Order: Lampriformes, Family: Trachipteridae
# Cache hit for genus 'Lophotus': Order: Lampriformes, Family: Lophotidae
# Cache hit for genus 'Lophotus': Order: Lampriformes, Family: Lophotidae
# Cache hit for genus 'Megacataetyx': Order: Ophidiiformes, Family: Bythitidae
# Adding new order: Ophidiiformes
# Cache hit for genus 'Bidenichthys': Order: Ophidiiformes, Family: Bythitidae
# Cache hit for genus 'Cataetyx': Order: Ophidiiformes, Family: Bythitidae
# Cache hit for genus 'Cataetyx': Order: Ophidiiformes, Family: Bythitidae
# Cache hit for genus 'Barathronus': Order: Ophidiiformes, Family: Aphyonidae
# Cache hit for genus 'Cataetyx': Order: Ophidiiformes, Family: Bythitidae
# Cache hit for genus 'Diplacanthopoma': Order: Ophidiiformes, Family: Bythitidae
# Cache hit for genus 'Diplacanthopoma': Order: Ophidiiformes, Family: Bythitidae
# Cache hit for genus 'Parabrotula': Order: Ophidiiformes, Family: Parabrotulidae
# Cache hit for genus 'Brosmophyciops': Order: Ophidiiformes, Family: Bythitidae
# Cache hit for genus 'Brosmophycis': Order: Ophidiiformes, Family: Bythitidae
# Cache hit for genus 'Lucifuga': Order: Ophidiiformes, Family: Bythitidae
# Cache hit for genus 'Lucifuga': Order: Ophidiiformes, Family: Bythitidae
# Cache hit for genus 'Lucifuga': Order: Ophidiiformes, Family: Bythitidae
# Cache hit for genus 'Diancistrus': Order: Ophidiiformes, Family: Bythitidae
# Cache hit for genus 'Diancistrus': Order: Ophidiiformes, Family: Bythitidae
# Cache hit for genus 'Dinematichthys': Order: Ophidiiformes, Family: Bythitidae
# Cache hit for genus 'Typhlias': Order: Ophidiiformes, Family: Dinematichthyidae
# Cache hit for genus 'Ogilbia': Order: Ophidiiformes, Family: Bythitidae
# Cache hit for genus 'Ogilbichthys': Order: Ophidiiformes, Family: Bythitidae
# Cache hit for genus 'Neobythites': Order: Ophidiiformes, Family: Ophidiidae
# Cache hit for genus 'Sirembo': Order: Ophidiiformes, Family: Ophidiidae
# Cache hit for genus 'Hoplobrotula': Order: Ophidiiformes, Family: Ophidiidae
# Cache hit for genus 'Lamprogrammus': Order: Ophidiiformes, Family: Ophidiidae
# Cache hit for genus 'Pyramodon': Order: Ophidiiformes, Family: Carapidae
# Cache hit for genus 'Onuxodon': Order: Ophidiiformes, Family: Carapidae
# Cache hit for genus 'Carapus': Order: Ophidiiformes, Family: Carapidae
# Cache hit for genus 'Carapus': Order: Ophidiiformes, Family: Carapidae
# Cache hit for genus 'Echiodon': Order: Ophidiiformes, Family: Carapidae
# Cache hit for genus 'Petrotyx': Order: Ophidiiformes, Family: Ophidiidae
# Cache hit for genus 'Genypterus': Order: Ophidiiformes, Family: Ophidiidae
# Cache hit for genus 'Genypterus': Order: Ophidiiformes, Family: Ophidiidae
# Cache hit for genus 'Genypterus': Order: Ophidiiformes, Family: Ophidiidae
# Cache hit for genus 'Genypterus': Order: Ophidiiformes, Family: Ophidiidae
# Cache hit for genus 'Genypterus': Order: Ophidiiformes, Family: Ophidiidae
# Cache hit for genus 'Chilara': Order: Ophidiiformes, Family: Ophidiidae
# Cache hit for genus 'Ophidion': Order: Ophidiiformes, Family: Ophidiidae
# Cache hit for genus 'Ophidion': Order: Ophidiiformes, Family: Ophidiidae
# Cache hit for genus 'Ophidion': Order: Ophidiiformes, Family: Ophidiidae
# Cache hit for genus 'Raneya': Order: Ophidiiformes, Family: Ophidiidae
# Cache hit for genus 'Lepophidium': Order: Ophidiiformes, Family: Ophidiidae
# Cache hit for genus 'Lepophidium': Order: Ophidiiformes, Family: Ophidiidae
# Cache hit for genus 'Lepophidium': Order: Ophidiiformes, Family: Ophidiidae
# Cache hit for genus 'Genypterus': Order: Ophidiiformes, Family: Ophidiidae
# Cache hit for genus 'Neobythites': Order: Ophidiiformes, Family: Ophidiidae
# Cache hit for genus 'Dannevigia': Order: Ophidiiformes, Family: Ophidiidae
# Cache hit for genus 'Monomitopus': Order: Ophidiiformes, Family: Ophidiidae
# Cache hit for genus 'Dicrolene': Order: Ophidiiformes, Family: Ophidiidae
# Cache hit for genus 'Brotulotaenia': Order: Ophidiiformes, Family: Ophidiidae
# Cache hit for genus 'Brotulotaenia': Order: Ophidiiformes, Family: Ophidiidae
# Cache hit for genus 'Lamprogrammus': Order: Ophidiiformes, Family: Ophidiidae
# Cache hit for genus 'Neobythites': Order: Ophidiiformes, Family: Ophidiidae
# Cache hit for genus 'Neobythites': Order: Ophidiiformes, Family: Ophidiidae
# Cache hit for genus 'Bassogigas': Order: Ophidiiformes, Family: Ophidiidae
# Cache hit for genus 'Apagesoma': Order: Ophidiiformes, Family: Ophidiidae
# Cache hit for genus 'Holcomycteronus': Order: Ophidiiformes, Family: Ophidiidae
# Cache hit for genus 'Ventichthys': Order: Ophidiiformes, Family: Ophidiidae
# Cache hit for genus 'Porogadus': Order: Ophidiiformes, Family: Ophidiidae
# Cache hit for genus 'Brotula': Order: Ophidiiformes, Family: Ophidiidae
# Cache hit for genus 'Brotula': Order: Ophidiiformes, Family: Ophidiidae
# Cache hit for genus 'Acanthonus': Order: Ophidiiformes, Family: Ophidiidae
# Cache hit for genus 'Aphyonus': Order: Ophidiiformes, Family: Aphyonidae
# Cache hit for genus 'Bassozetus': Order: Ophidiiformes, Family: Ophidiidae
# Cache hit for genus 'Selachophidium': Order: Ophidiiformes, Family: Ophidiidae
# Cache hit for genus 'Chaetodon': Order: Perciformes, Family: Chaetodontidae
# Adding new order: Perciformes
# Cache hit for genus 'Chaetodon': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Chaetodon': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Chaetodon': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Chaetodon': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Chaetodon': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Chaetodon': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Chaetodon': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Chaetodon': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Chaetodon': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Chaetodon': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Chaetodon': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Chaetodon': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Chaetodon': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Chaetodon': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Chaetodon': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Chaetodon': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Chaetodon': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Chaetodon': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Chaetodon': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Chaetodon': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Chaetodon': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Chaetodon': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Chaetodon': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Chaetodon': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Chaetodon': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Chaetodon': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Chaetodon': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Chaetodon': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Chaetodon': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Parachaetodon': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Chaetodon': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Chaetodon': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Chaetodon': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Chaetodon': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Chaetodon': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Chaetodon': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Chaetodon': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Chaetodon': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Chaetodon': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Chaetodon': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Chaetodon': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Chaetodon': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Chaetodon': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Chaetodon': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Chaetodon': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Chaetodon': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Chaetodon': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Chaetodon': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Chaetodon': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Chaetodon': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Chaetodon': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Chaetodon': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Chaetodon': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Chaetodon': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Chaetodon': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Chaetodon': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Chaetodon': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Chaetodon': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Chaetodon': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Chaetodon': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Chaetodon': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Chaetodon': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Chaetodon': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Chaetodon': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Chaetodon': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Chaetodon': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Chaetodon': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Chaetodon': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Chaetodon': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Chaetodon': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Chaetodon': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Chaetodon': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Prognathodes': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Prognathodes': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Prognathodes': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Prognathodes': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Chelmonops': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Chelmonops': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Chelmon': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Chelmon': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Chelmon': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Coradion': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Coradion': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Coradion': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Amphichaetodon': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Amphichaetodon': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Johnrandallia': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Heniochus': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Heniochus': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Heniochus': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Heniochus': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Heniochus': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Heniochus': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Heniochus': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Hemitaurichthys': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Hemitaurichthys': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Hemitaurichthys': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Forcipiger': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Forcipiger': Order: Perciformes, Family: Chaetodontidae
# Cache hit for genus 'Gazza': Order: Perciformes, Family: Leiognathidae
# Cache hit for genus 'Gazza': Order: Perciformes, Family: Leiognathidae
# Cache hit for genus 'Gazza': Order: Perciformes, Family: Leiognathidae
# Cache hit for genus 'Gazza': Order: Perciformes, Family: Leiognathidae
# Cache hit for genus 'Gazza': Order: Perciformes, Family: Leiognathidae
# Cache hit for genus 'Leiognathus': Order: Perciformes, Family: Leiognathidae
# Cache hit for genus 'Deveximentum': Order: Perciformes, Family: Leiognathidae
# Cache hit for genus 'Deveximentum': Order: Perciformes, Family: Leiognathidae
# Cache hit for genus 'Deveximentum': Order: Perciformes, Family: Leiognathidae
# Cache hit for genus 'Deveximentum': Order: Perciformes, Family: Leiognathidae
# Cache hit for genus 'Photopectoralis': Order: Perciformes, Family: Leiognathidae
# Cache hit for genus 'Photopectoralis': Order: Perciformes, Family: Leiognathidae
# Cache hit for genus 'Photopectoralis': Order: Perciformes, Family: Leiognathidae
# Cache hit for genus 'Photopectoralis': Order: Perciformes, Family: Leiognathidae
# Cache hit for genus 'Photopectoralis': Order: Perciformes, Family: Leiognathidae
# Cache hit for genus 'Eubleekeria': Order: Perciformes, Family: Leiognathidae
# Cache hit for genus 'Eubleekeria': Order: Perciformes, Family: Leiognathidae
# Cache hit for genus 'Karalla': Order: Perciformes, Family: Leiognathidae
# Cache hit for genus 'Karalla': Order: Perciformes, Family: Leiognathidae
# Cache hit for genus 'Nuchequula': Order: Perciformes, Family: Leiognathidae
# Cache hit for genus 'Nuchequula': Order: Perciformes, Family: Leiognathidae
# Cache hit for genus 'Nuchequula': Order: Perciformes, Family: Leiognathidae
# Cache hit for genus 'Nuchequula': Order: Perciformes, Family: Leiognathidae
# Cache hit for genus 'Nuchequula': Order: Perciformes, Family: Leiognathidae
# Cache hit for genus 'Equulites': Order: Perciformes, Family: Leiognathidae
# Cache hit for genus 'Equulites': Order: Perciformes, Family: Leiognathidae
# Cache hit for genus 'Equulites': Order: Perciformes, Family: Leiognathidae
# Cache hit for genus 'Equulites': Order: Perciformes, Family: Leiognathidae
# Cache hit for genus 'Equulites': Order: Perciformes, Family: Leiognathidae
# Cache hit for genus 'Equulites': Order: Perciformes, Family: Leiognathidae
# Cache hit for genus 'Leiognathus': Order: Perciformes, Family: Leiognathidae
# Cache hit for genus 'Leiognathus': Order: Perciformes, Family: Leiognathidae
# Cache hit for genus 'Leiognathus': Order: Perciformes, Family: Leiognathidae
# Cache hit for genus 'Aurigequula': Order: Perciformes, Family: Leiognathidae
# Cache hit for genus 'Aurigequula': Order: Perciformes, Family: Leiognathidae
# Cache hit for genus 'Centropyge': Order: Perciformes, Family: Pomacanthidae
# Cache hit for genus 'Centropyge': Order: Perciformes, Family: Pomacanthidae
# Cache hit for genus 'Centropyge': Order: Perciformes, Family: Pomacanthidae
# Cache hit for genus 'Centropyge': Order: Perciformes, Family: Pomacanthidae
# Cache hit for genus 'Centropyge': Order: Perciformes, Family: Pomacanthidae
# Cache hit for genus 'Centropyge': Order: Perciformes, Family: Pomacanthidae
# Cache hit for genus 'Centropyge': Order: Perciformes, Family: Pomacanthidae
# Cache hit for genus 'Centropyge': Order: Perciformes, Family: Pomacanthidae
# Cache hit for genus 'Centropyge': Order: Perciformes, Family: Pomacanthidae
# Cache hit for genus 'Centropyge': Order: Perciformes, Family: Pomacanthidae
# Cache hit for genus 'Centropyge': Order: Perciformes, Family: Pomacanthidae
# Cache hit for genus 'Centropyge': Order: Perciformes, Family: Pomacanthidae
# Cache hit for genus 'Genicanthus': Order: Perciformes, Family: Pomacanthidae
# Cache hit for genus 'Genicanthus': Order: Perciformes, Family: Pomacanthidae
# Cache hit for genus 'Genicanthus': Order: Perciformes, Family: Pomacanthidae
# Cache hit for genus 'Genicanthus': Order: Perciformes, Family: Pomacanthidae
# Cache hit for genus 'Genicanthus': Order: Perciformes, Family: Pomacanthidae
# Cache hit for genus 'Paracentropyge': Order: Perciformes, Family: Pomacanthidae
# Cache hit for genus 'Centropyge': Order: Perciformes, Family: Pomacanthidae
# Cache hit for genus 'Apolemichthys': Order: Perciformes, Family: Pomacanthidae
# Cache hit for genus 'Apolemichthys': Order: Perciformes, Family: Pomacanthidae
# Cache hit for genus 'Apolemichthys': Order: Perciformes, Family: Pomacanthidae
# Cache hit for genus 'Centropyge': Order: Perciformes, Family: Pomacanthidae
# Cache hit for genus 'Centropyge': Order: Perciformes, Family: Pomacanthidae
# Cache hit for genus 'Centropyge': Order: Perciformes, Family: Pomacanthidae
# Cache hit for genus 'Pygoplites': Order: Perciformes, Family: Pomacanthidae
# Cache hit for genus 'Centropyge': Order: Perciformes, Family: Pomacanthidae
# Cache hit for genus 'Centropyge': Order: Perciformes, Family: Pomacanthidae
# Cache hit for genus 'Centropyge': Order: Perciformes, Family: Pomacanthidae
# Cache hit for genus 'Centropyge': Order: Perciformes, Family: Pomacanthidae
# Cache hit for genus 'Centropyge': Order: Perciformes, Family: Pomacanthidae
# Cache hit for genus 'Centropyge': Order: Perciformes, Family: Pomacanthidae
# Cache hit for genus 'Centropyge': Order: Perciformes, Family: Pomacanthidae
# Cache hit for genus 'Centropyge': Order: Perciformes, Family: Pomacanthidae
# Cache hit for genus 'Centropyge': Order: Perciformes, Family: Pomacanthidae
# Cache hit for genus 'Holacanthus': Order: Perciformes, Family: Pomacanthidae
# Cache hit for genus 'Holacanthus': Order: Perciformes, Family: Pomacanthidae
# Cache hit for genus 'Holacanthus': Order: Perciformes, Family: Pomacanthidae
# Cache hit for genus 'Holacanthus': Order: Perciformes, Family: Pomacanthidae
# Cache hit for genus 'Holacanthus': Order: Perciformes, Family: Pomacanthidae
# Cache hit for genus 'Holacanthus': Order: Perciformes, Family: Pomacanthidae
# Cache hit for genus 'Holacanthus': Order: Perciformes, Family: Pomacanthidae
# Cache hit for genus 'Pomacanthus': Order: Perciformes, Family: Pomacanthidae
# Cache hit for genus 'Pomacanthus': Order: Perciformes, Family: Pomacanthidae
# Cache hit for genus 'Pomacanthus': Order: Perciformes, Family: Pomacanthidae
# Cache hit for genus 'Pomacanthus': Order: Perciformes, Family: Pomacanthidae
# Cache hit for genus 'Pomacanthus': Order: Perciformes, Family: Pomacanthidae
# Cache hit for genus 'Pomacanthus': Order: Perciformes, Family: Pomacanthidae
# Cache hit for genus 'Pomacanthus': Order: Perciformes, Family: Pomacanthidae
# Cache hit for genus 'Pomacanthus': Order: Perciformes, Family: Pomacanthidae
# Cache hit for genus 'Pomacanthus': Order: Perciformes, Family: Pomacanthidae
# Cache hit for genus 'Pomacanthus': Order: Perciformes, Family: Pomacanthidae
# Cache hit for genus 'Pomacanthus': Order: Perciformes, Family: Pomacanthidae
# Cache hit for genus 'Pomacanthus': Order: Perciformes, Family: Pomacanthidae
# Cache hit for genus 'Pomacanthus': Order: Perciformes, Family: Pomacanthidae
# Cache hit for genus 'Chaetodontoplus': Order: Perciformes, Family: Pomacanthidae
# Cache hit for genus 'Chaetodontoplus': Order: Perciformes, Family: Pomacanthidae
# Cache hit for genus 'Chaetodontoplus': Order: Perciformes, Family: Pomacanthidae
# Cache hit for genus 'Chaetodontoplus': Order: Perciformes, Family: Pomacanthidae
# Cache hit for genus 'Chaetodontoplus': Order: Perciformes, Family: Pomacanthidae
# Cache hit for genus 'Chaetodontoplus': Order: Perciformes, Family: Pomacanthidae
# Cache hit for genus 'Luvarus': Order: Perciformes, Family: Luvaridae
# Cache hit for genus 'Zanclus': Order: Perciformes, Family: Zanclidae
# Cache hit for genus 'Prionurus': Order: Perciformes, Family: Acanthuridae
# Cache hit for genus 'Prionurus': Order: Perciformes, Family: Acanthuridae
# Cache hit for genus 'Prionurus': Order: Perciformes, Family: Acanthuridae
# Cache hit for genus 'Prionurus': Order: Perciformes, Family: Acanthuridae
# Cache hit for genus 'Prionurus': Order: Perciformes, Family: Acanthuridae
# Cache hit for genus 'Prionurus': Order: Perciformes, Family: Acanthuridae
# Cache hit for genus 'Prionurus': Order: Perciformes, Family: Acanthuridae
# Cache hit for genus 'Zebrasoma': Order: Perciformes, Family: Acanthuridae
# Cache hit for genus 'Zebrasoma': Order: Perciformes, Family: Acanthuridae
# Cache hit for genus 'Zebrasoma': Order: Perciformes, Family: Acanthuridae
# Cache hit for genus 'Zebrasoma': Order: Perciformes, Family: Acanthuridae
# Cache hit for genus 'Zebrasoma': Order: Perciformes, Family: Acanthuridae
# Cache hit for genus 'Zebrasoma': Order: Perciformes, Family: Acanthuridae
# Cache hit for genus 'Paracanthurus': Order: Perciformes, Family: Acanthuridae
# Cache hit for genus 'Acanthurus': Order: Perciformes, Family: Acanthuridae
# Cache hit for genus 'Acanthurus': Order: Perciformes, Family: Acanthuridae
# Cache hit for genus 'Acanthurus': Order: Perciformes, Family: Acanthuridae
# Cache hit for genus 'Acanthurus': Order: Perciformes, Family: Acanthuridae
# Cache hit for genus 'Acanthurus': Order: Perciformes, Family: Acanthuridae
# Cache hit for genus 'Acanthurus': Order: Perciformes, Family: Acanthuridae
# Cache hit for genus 'Acanthurus': Order: Perciformes, Family: Acanthuridae
# Cache hit for genus 'Acanthurus': Order: Perciformes, Family: Acanthuridae
# Cache hit for genus 'Acanthurus': Order: Perciformes, Family: Acanthuridae
# Cache hit for genus 'Acanthurus': Order: Perciformes, Family: Acanthuridae
# Cache hit for genus 'Acanthurus': Order: Perciformes, Family: Acanthuridae
# Cache hit for genus 'Acanthurus': Order: Perciformes, Family: Acanthuridae
# Cache hit for genus 'Acanthurus': Order: Perciformes, Family: Acanthuridae
# Cache hit for genus 'Acanthurus': Order: Perciformes, Family: Acanthuridae
# Cache hit for genus 'Acanthurus': Order: Perciformes, Family: Acanthuridae
# Cache hit for genus 'Acanthurus': Order: Perciformes, Family: Acanthuridae
# Cache hit for genus 'Acanthurus': Order: Perciformes, Family: Acanthuridae
# Cache hit for genus 'Acanthurus': Order: Perciformes, Family: Acanthuridae
# Cache hit for genus 'Acanthurus': Order: Perciformes, Family: Acanthuridae
# Cache hit for genus 'Acanthurus': Order: Perciformes, Family: Acanthuridae
# Cache hit for genus 'Acanthurus': Order: Perciformes, Family: Acanthuridae
# Cache hit for genus 'Acanthurus': Order: Perciformes, Family: Acanthuridae
# Cache hit for genus 'Acanthurus': Order: Perciformes, Family: Acanthuridae
# Cache hit for genus 'Acanthurus': Order: Perciformes, Family: Acanthuridae
# Cache hit for genus 'Ctenochaetus': Order: Perciformes, Family: Acanthuridae
# Cache hit for genus 'Ctenochaetus': Order: Perciformes, Family: Acanthuridae
# Cache hit for genus 'Ctenochaetus': Order: Perciformes, Family: Acanthuridae
# Cache hit for genus 'Ctenochaetus': Order: Perciformes, Family: Acanthuridae
# Cache hit for genus 'Ctenochaetus': Order: Perciformes, Family: Acanthuridae
# Cache hit for genus 'Ctenochaetus': Order: Perciformes, Family: Acanthuridae
# Cache hit for genus 'Acanthurus': Order: Perciformes, Family: Acanthuridae
# Cache hit for genus 'Ctenochaetus': Order: Perciformes, Family: Acanthuridae
# Cache hit for genus 'Ctenochaetus': Order: Perciformes, Family: Acanthuridae
# Cache hit for genus 'Acanthurus': Order: Perciformes, Family: Acanthuridae
# Cache hit for genus 'Acanthurus': Order: Perciformes, Family: Acanthuridae
# Cache hit for genus 'Acanthurus': Order: Perciformes, Family: Acanthuridae
# Cache hit for genus 'Naso': Order: Perciformes, Family: Acanthuridae
# Cache hit for genus 'Naso': Order: Perciformes, Family: Acanthuridae
# Cache hit for genus 'Naso': Order: Perciformes, Family: Acanthuridae
# Cache hit for genus 'Naso': Order: Perciformes, Family: Acanthuridae
# Cache hit for genus 'Naso': Order: Perciformes, Family: Acanthuridae
# Cache hit for genus 'Naso': Order: Perciformes, Family: Acanthuridae
# Cache hit for genus 'Naso': Order: Perciformes, Family: Acanthuridae
# Cache hit for genus 'Naso': Order: Perciformes, Family: Acanthuridae
# Cache hit for genus 'Naso': Order: Perciformes, Family: Acanthuridae
# Cache hit for genus 'Naso': Order: Perciformes, Family: Acanthuridae
# Cache hit for genus 'Naso': Order: Perciformes, Family: Acanthuridae
# Cache hit for genus 'Naso': Order: Perciformes, Family: Acanthuridae
# Cache hit for genus 'Naso': Order: Perciformes, Family: Acanthuridae
# Cache hit for genus 'Naso': Order: Perciformes, Family: Acanthuridae
# Cache hit for genus 'Naso': Order: Perciformes, Family: Acanthuridae
# Cache hit for genus 'Naso': Order: Perciformes, Family: Acanthuridae
# Cache hit for genus 'Naso': Order: Perciformes, Family: Acanthuridae
# Cache hit for genus 'Naso': Order: Perciformes, Family: Acanthuridae
# Cache hit for genus 'Naso': Order: Perciformes, Family: Acanthuridae
# Cache hit for genus 'Caulolatilus': Order: Perciformes, Family: Malacanthidae
# Cache hit for genus 'Caulolatilus': Order: Perciformes, Family: Malacanthidae
# Cache hit for genus 'Caulolatilus': Order: Perciformes, Family: Malacanthidae
# Cache hit for genus 'Hoplolatilus': Order: Perciformes, Family: Malacanthidae
# Cache hit for genus 'Malacanthus': Order: Perciformes, Family: Malacanthidae
# Cache hit for genus 'Malacanthus': Order: Perciformes, Family: Malacanthidae
# Cache hit for genus 'Malacanthus': Order: Perciformes, Family: Malacanthidae
# Cache hit for genus 'Branchiostegus': Order: Perciformes, Family: Malacanthidae
# Cache hit for genus 'Branchiostegus': Order: Perciformes, Family: Malacanthidae
# Cache hit for genus 'Branchiostegus': Order: Perciformes, Family: Malacanthidae
# Cache hit for genus 'Branchiostegus': Order: Perciformes, Family: Malacanthidae
# Cache hit for genus 'Branchiostegus': Order: Perciformes, Family: Malacanthidae
# Cache hit for genus 'Branchiostegus': Order: Perciformes, Family: Malacanthidae
# Cache hit for genus 'Caulolatilus': Order: Perciformes, Family: Malacanthidae
# Cache hit for genus 'Lopholatilus': Order: Perciformes, Family: Malacanthidae
# Cache hit for genus 'Branchiostegus': Order: Perciformes, Family: Malacanthidae
# Cache hit for genus 'Lopholatilus': Order: Perciformes, Family: Malacanthidae
# Cache hit for genus 'Hoplolatilus': Order: Perciformes, Family: Malacanthidae
# Cache hit for genus 'Hoplolatilus': Order: Perciformes, Family: Malacanthidae
# Cache hit for genus 'Hoplolatilus': Order: Perciformes, Family: Malacanthidae
# Cache hit for genus 'Callanthias': Order: Perciformes, Family: Callanthiidae
# Cache hit for genus 'Grammatonotus': Order: Perciformes, Family: Callanthiidae
# Cache hit for genus 'Pinjalo': Order: Perciformes, Family: Lutjanidae
# Cache hit for genus 'Apsilus': Order: Perciformes, Family: Lutjanidae
# Cache hit for genus 'Paracaesio': Order: Perciformes, Family: Lutjanidae
# Cache hit for genus 'Paracaesio': Order: Perciformes, Family: Lutjanidae
# Cache hit for genus 'Aphareus': Order: Perciformes, Family: Lutjanidae
# Cache hit for genus 'Aphareus': Order: Perciformes, Family: Lutjanidae
# Cache hit for genus 'Pristipomoides': Order: Perciformes, Family: Lutjanidae
# Cache hit for genus 'Pristipomoides': Order: Perciformes, Family: Lutjanidae
# Cache hit for genus 'Pristipomoides': Order: Perciformes, Family: Lutjanidae
# Cache hit for genus 'Pristipomoides': Order: Perciformes, Family: Lutjanidae
# Cache hit for genus 'Pristipomoides': Order: Perciformes, Family: Lutjanidae
# Cache hit for genus 'Pristipomoides': Order: Perciformes, Family: Lutjanidae
# Cache hit for genus 'Aprion': Order: Perciformes, Family: Lutjanidae
# Cache hit for genus 'Etelis': Order: Perciformes, Family: Lutjanidae
# Cache hit for genus 'Etelis': Order: Perciformes, Family: Lutjanidae
# Cache hit for genus 'Lutjanus': Order: Perciformes, Family: Lutjanidae
# Cache hit for genus 'Lutjanus': Order: Perciformes, Family: Lutjanidae
# Cache hit for genus 'Lutjanus': Order: Perciformes, Family: Lutjanidae
# Cache hit for genus 'Lutjanus': Order: Perciformes, Family: Lutjanidae
# Cache hit for genus 'Lutjanus': Order: Perciformes, Family: Lutjanidae
# Cache hit for genus 'Lutjanus': Order: Perciformes, Family: Lutjanidae
# Cache hit for genus 'Lutjanus': Order: Perciformes, Family: Lutjanidae
# Cache hit for genus 'Lutjanus': Order: Perciformes, Family: Lutjanidae
# Cache hit for genus 'Lutjanus': Order: Perciformes, Family: Lutjanidae
# Cache hit for genus 'Lutjanus': Order: Perciformes, Family: Lutjanidae
# Cache hit for genus 'Lutjanus': Order: Perciformes, Family: Lutjanidae
# Cache hit for genus 'Lutjanus': Order: Perciformes, Family: Lutjanidae
# Cache hit for genus 'Lutjanus': Order: Perciformes, Family: Lutjanidae
# Cache hit for genus 'Lutjanus': Order: Perciformes, Family: Lutjanidae
# Cache hit for genus 'Lutjanus': Order: Perciformes, Family: Lutjanidae
# Cache hit for genus 'Lutjanus': Order: Perciformes, Family: Lutjanidae
# Cache hit for genus 'Lutjanus': Order: Perciformes, Family: Lutjanidae
# Cache hit for genus 'Lutjanus': Order: Perciformes, Family: Lutjanidae
# Cache hit for genus 'Lutjanus': Order: Perciformes, Family: Lutjanidae
# Cache hit for genus 'Lutjanus': Order: Perciformes, Family: Lutjanidae
# Cache hit for genus 'Lutjanus': Order: Perciformes, Family: Lutjanidae
# Cache hit for genus 'Lutjanus': Order: Perciformes, Family: Lutjanidae
# Cache hit for genus 'Lutjanus': Order: Perciformes, Family: Lutjanidae
# Cache hit for genus 'Lutjanus': Order: Perciformes, Family: Lutjanidae
# Cache hit for genus 'Lutjanus': Order: Perciformes, Family: Lutjanidae
# Cache hit for genus 'Lutjanus': Order: Perciformes, Family: Lutjanidae
# Cache hit for genus 'Lutjanus': Order: Perciformes, Family: Lutjanidae
# Cache hit for genus 'Lutjanus': Order: Perciformes, Family: Lutjanidae
# Cache hit for genus 'Ocyurus': Order: Perciformes, Family: Lutjanidae
# Cache hit for genus 'Lutjanus': Order: Perciformes, Family: Lutjanidae
# Cache hit for genus 'Lutjanus': Order: Perciformes, Family: Lutjanidae
# Cache hit for genus 'Lutjanus': Order: Perciformes, Family: Lutjanidae
# Cache hit for genus 'Lutjanus': Order: Perciformes, Family: Lutjanidae
# Cache hit for genus 'Rhomboplites': Order: Perciformes, Family: Lutjanidae
# Cache hit for genus 'Lutjanus': Order: Perciformes, Family: Lutjanidae
# Cache hit for genus 'Lutjanus': Order: Perciformes, Family: Lutjanidae
# Cache hit for genus 'Lutjanus': Order: Perciformes, Family: Lutjanidae
# Cache hit for genus 'Lutjanus': Order: Perciformes, Family: Lutjanidae
# Cache hit for genus 'Lutjanus': Order: Perciformes, Family: Lutjanidae
# Cache hit for genus 'Lutjanus': Order: Perciformes, Family: Lutjanidae
# Cache hit for genus 'Lutjanus': Order: Perciformes, Family: Lutjanidae
# Cache hit for genus 'Lutjanus': Order: Perciformes, Family: Lutjanidae
# Cache hit for genus 'Lutjanus': Order: Perciformes, Family: Lutjanidae
# Cache hit for genus 'Lutjanus': Order: Perciformes, Family: Lutjanidae
# Cache hit for genus 'Lutjanus': Order: Perciformes, Family: Lutjanidae
# Cache hit for genus 'Lutjanus': Order: Perciformes, Family: Lutjanidae
# Cache hit for genus 'Lutjanus': Order: Perciformes, Family: Lutjanidae
# Cache hit for genus 'Lutjanus': Order: Perciformes, Family: Lutjanidae
# Cache hit for genus 'Lutjanus': Order: Perciformes, Family: Lutjanidae
# Cache hit for genus 'Caesio': Order: Perciformes, Family: Caesionidae
# Cache hit for genus 'Caesio': Order: Perciformes, Family: Caesionidae
# Cache hit for genus 'Pterocaesio': Order: Perciformes, Family: Caesionidae
# Cache hit for genus 'Pterocaesio': Order: Perciformes, Family: Caesionidae
# Cache hit for genus 'Pterocaesio': Order: Perciformes, Family: Caesionidae
# Cache hit for genus 'Pterocaesio': Order: Perciformes, Family: Caesionidae
# Cache hit for genus 'Pterocaesio': Order: Perciformes, Family: Caesionidae
# Cache hit for genus 'Caesio': Order: Perciformes, Family: Caesionidae
# Cache hit for genus 'Gymnocaesio': Order: Perciformes, Family: Caesionidae
# Cache hit for genus 'Dipterygonotus': Order: Perciformes, Family: Caesionidae
# Cache hit for genus 'Pterocaesio': Order: Perciformes, Family: Caesionidae
# Cache hit for genus 'Caesio': Order: Perciformes, Family: Caesionidae
# Cache hit for genus 'Caesio': Order: Perciformes, Family: Caesionidae
# Cache hit for genus 'Caesio': Order: Perciformes, Family: Caesionidae
# Cache hit for genus 'Macolor': Order: Perciformes, Family: Lutjanidae
# Cache hit for genus 'Symphorichthys': Order: Perciformes, Family: Lutjanidae
# Cache hit for genus 'Symphorus': Order: Perciformes, Family: Lutjanidae
# Cache hit for genus 'Plectorhinchus': Order: Perciformes, Family: Haemulidae
# Cache hit for genus 'Diagramma': Order: Perciformes, Family: Haemulidae
# Cache hit for genus 'Diagramma': Order: Perciformes, Family: Haemulidae
# Cache hit for genus 'Plectorhinchus': Order: Perciformes, Family: Haemulidae
# Cache hit for genus 'Plectorhinchus': Order: Perciformes, Family: Haemulidae
# Cache hit for genus 'Diagramma': Order: Perciformes, Family: Haemulidae
# Cache hit for genus 'Plectorhinchus': Order: Perciformes, Family: Haemulidae
# Cache hit for genus 'Plectorhinchus': Order: Perciformes, Family: Haemulidae
# Cache hit for genus 'Plectorhinchus': Order: Perciformes, Family: Haemulidae
# Cache hit for genus 'Plectorhinchus': Order: Perciformes, Family: Haemulidae
# Cache hit for genus 'Plectorhinchus': Order: Perciformes, Family: Haemulidae
# Cache hit for genus 'Plectorhinchus': Order: Perciformes, Family: Haemulidae
# Cache hit for genus 'Plectorhinchus': Order: Perciformes, Family: Haemulidae
# Cache hit for genus 'Plectorhinchus': Order: Perciformes, Family: Haemulidae
# Cache hit for genus 'Plectorhinchus': Order: Perciformes, Family: Haemulidae
# Cache hit for genus 'Plectorhinchus': Order: Perciformes, Family: Haemulidae
# Cache hit for genus 'Plectorhinchus': Order: Perciformes, Family: Haemulidae
# Cache hit for genus 'Plectorhinchus': Order: Perciformes, Family: Haemulidae
# Cache hit for genus 'Plectorhinchus': Order: Perciformes, Family: Haemulidae
# Cache hit for genus 'Plectorhinchus': Order: Perciformes, Family: Haemulidae
# Cache hit for genus 'Plectorhinchus': Order: Perciformes, Family: Haemulidae
# Cache hit for genus 'Plectorhinchus': Order: Perciformes, Family: Haemulidae
# Cache hit for genus 'Plectorhinchus': Order: Perciformes, Family: Haemulidae
# Cache hit for genus 'Plectorhinchus': Order: Perciformes, Family: Haemulidae
# Cache hit for genus 'Plectorhinchus': Order: Perciformes, Family: Haemulidae
# Cache hit for genus 'Parapristipoma': Order: Perciformes, Family: Haemulidae
# Cache hit for genus 'Parapristipoma': Order: Perciformes, Family: Haemulidae
# Cache hit for genus 'Brachygenys': Order: Perciformes, Family: Haemulidae
# Cache hit for genus 'Brachygenys': Order: Perciformes, Family: Haemulidae
# Cache hit for genus 'Brachygenys': Order: Perciformes, Family: Haemulidae
# Cache hit for genus 'Haemulon': Order: Perciformes, Family: Haemulidae
# Cache hit for genus 'Haemulon': Order: Perciformes, Family: Haemulidae
# Cache hit for genus 'Haemulon': Order: Perciformes, Family: Haemulidae
# Cache hit for genus 'Haemulon': Order: Perciformes, Family: Haemulidae
# Cache hit for genus 'Haemulon': Order: Perciformes, Family: Haemulidae
# Cache hit for genus 'Haemulon': Order: Perciformes, Family: Haemulidae
# Cache hit for genus 'Haemulon': Order: Perciformes, Family: Haemulidae
# Cache hit for genus 'Haemulon': Order: Perciformes, Family: Haemulidae
# Cache hit for genus 'Haemulon': Order: Perciformes, Family: Haemulidae
# Cache hit for genus 'Haemulon': Order: Perciformes, Family: Haemulidae
# Cache hit for genus 'Haemulon': Order: Perciformes, Family: Haemulidae
# Cache hit for genus 'Haemulon': Order: Perciformes, Family: Haemulidae
# Cache hit for genus 'Haemulon': Order: Perciformes, Family: Haemulidae
# Cache hit for genus 'Haemulon': Order: Perciformes, Family: Haemulidae
# Cache hit for genus 'Haemulon': Order: Perciformes, Family: Haemulidae
# Cache hit for genus 'Haemulon': Order: Perciformes, Family: Haemulidae
# Cache hit for genus 'Haemulon': Order: Perciformes, Family: Haemulidae
# Cache hit for genus 'Haemulon': Order: Perciformes, Family: Haemulidae
# Cache hit for genus 'Haemulon': Order: Perciformes, Family: Haemulidae
# Cache hit for genus 'Haemulon': Order: Perciformes, Family: Haemulidae
# Cache hit for genus 'Haemulon': Order: Perciformes, Family: Haemulidae
# Cache hit for genus 'Anisotremus': Order: Perciformes, Family: Haemulidae
# Cache hit for genus 'Anisotremus': Order: Perciformes, Family: Haemulidae
# Cache hit for genus 'Anisotremus': Order: Perciformes, Family: Haemulidae
# Cache hit for genus 'Anisotremus': Order: Perciformes, Family: Haemulidae
# Cache hit for genus 'Anisotremus': Order: Perciformes, Family: Haemulidae
# Cache hit for genus 'Anisotremus': Order: Perciformes, Family: Haemulidae
# Cache hit for genus 'Anisotremus': Order: Perciformes, Family: Haemulidae
# ...
# Cache hit for genus 'Gymnothorax': Order: Anguilliformes, Family: Muraenidae
# Cache hit for genus 'Gymnothorax': Order: Anguilliformes, Family: Muraenidae
# Cache hit for genus 'Gymnothorax': Order: Anguilliformes, Family: Muraenidae
# Cache hit for genus 'Gymnothorax': Order: Anguilliformes, Family: Muraenidae
# Cache hit for genus 'Strophidon': Order: Anguilliformes, Family: Muraenidae
# Cache hit for genus 'Pseudechidna': Order: Anguilliformes, Family: Muraenidae
# Cache hit for genus 'Enchelycore': Order: Anguilliformes, Family: Muraenidae
# Cache hit for genus 'Gymnothorax': Order: Anguilliformes, Family: Muraenidae
# Cache hit for genus 'Gymnothorax': Order: Anguilliformes, Family: Muraenidae
# Cache hit for genus 'Gymnothorax': Order: Anguilliformes, Family: Muraenidae
# Cache hit for genus 'Gymnothorax': Order: Anguilliformes, Family: Muraenidae
# Cache hit for genus 'Gymnothorax': Order: Anguilliformes, Family: Muraenidae
# Cache hit for genus 'Gymnothorax': Order: Anguilliformes, Family: Muraenidae
# Cache hit for genus 'Echidna': Order: Anguilliformes, Family: Muraenidae
# Cache hit for genus 'Echidna': Order: Anguilliformes, Family: Muraenidae
# Cache hit for genus 'Gymnothorax': Order: Anguilliformes, Family: Muraenidae
# Cache hit for genus 'Gymnothorax': Order: Anguilliformes, Family: Muraenidae
# Cache hit for genus 'Gymnothorax': Order: Anguilliformes, Family: Muraenidae
# Cache hit for genus 'Muraena': Order: Anguilliformes, Family: Muraenidae
# Cache hit for genus 'Muraena': Order: Anguilliformes, Family: Muraenidae
# Cache hit for genus 'Muraena': Order: Anguilliformes, Family: Muraenidae
# Cache hit for genus 'Muraena': Order: Anguilliformes, Family: Muraenidae
# Cache hit for genus 'Muraena': Order: Anguilliformes, Family: Muraenidae
# Cache hit for genus 'Gymnothorax': Order: Anguilliformes, Family: Muraenidae
# Cache hit for genus 'Gymnothorax': Order: Anguilliformes, Family: Muraenidae
# Cache hit for genus 'Gymnomuraena': Order: Anguilliformes, Family: Muraenidae
# Cache hit for genus 'Gymnothorax': Order: Anguilliformes, Family: Muraenidae
# Cache hit for genus 'Uropterygius': Order: Anguilliformes, Family: Muraenidae
# Cache hit for genus 'Scuticaria': Order: Anguilliformes, Family: Muraenidae
# Cache hit for genus 'Scuticaria': Order: Anguilliformes, Family: Muraenidae
# Cache hit for genus 'Uropterygius': Order: Anguilliformes, Family: Muraenidae
# Cache hit for genus 'Uropterygius': Order: Anguilliformes, Family: Muraenidae
# Cache hit for genus 'Uropterygius': Order: Anguilliformes, Family: Muraenidae
# Cache hit for genus 'Uropterygius': Order: Anguilliformes, Family: Muraenidae
# Cache hit for genus 'Uropterygius': Order: Anguilliformes, Family: Muraenidae
# Cache hit for genus 'Anarchias': Order: Anguilliformes, Family: Muraenidae
# Cache hit for genus 'Pythonichthys': Order: Anguilliformes, Family: Heterenchelyidae
# Cache hit for genus 'Pythonichthys': Order: Anguilliformes, Family: Heterenchelyidae
# Cache hit for genus 'Protanguilla': Order: Anguilliformes, Family: Protanguillidae
# Cache hit for genus 'Meadia': Order: Anguilliformes, Family: Synaphobranchidae
# Cache hit for genus 'Synaphobranchus': Order: Anguilliformes, Family: Synaphobranchidae
# Cache hit for genus 'Synaphobranchus': Order: Anguilliformes, Family: Synaphobranchidae
# Cache hit for genus 'Diastobranchus': Order: Anguilliformes, Family: Synaphobranchidae
# Cache hit for genus 'Dysomma': Order: Anguilliformes, Family: Synaphobranchidae
# Cache hit for genus 'Ilyophis': Order: Anguilliformes, Family: Synaphobranchidae
# Cache hit for genus 'Meadia': Order: Anguilliformes, Family: Synaphobranchidae
# Cache hit for genus 'Simenchelys': Order: Anguilliformes, Family: Synaphobranchidae
# Cache hit for genus 'Histiobranchus': Order: Anguilliformes, Family: Synaphobranchidae
# Cache hit for genus 'Albula': Order: Albuliformes, Family: Albulidae
# Adding new order: Albuliformes
# Cache hit for genus 'Albula': Order: Albuliformes, Family: Albulidae
# Cache hit for genus 'Albula': Order: Albuliformes, Family: Albulidae
# Cache hit for genus 'Albula': Order: Albuliformes, Family: Albulidae
# Cache hit for genus 'Albula': Order: Albuliformes, Family: Albulidae
# Cache hit for genus 'Albula': Order: Albuliformes, Family: Albulidae
# Cache hit for genus 'Albula': Order: Albuliformes, Family: Albulidae
# Cache hit for genus 'Pterothrissus': Order: Albuliformes, Family: Albulidae
# Cache hit for genus 'Pantodon': Order: Osteoglossiformes, Family: Pantodontidae
# Adding new order: Osteoglossiformes
# Cache hit for genus 'Gymnarchus': Order: Osteoglossiformes, Family: Gymnarchidae
# Cache hit for genus 'Petrocephalus': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Petrocephalus': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Petrocephalus': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Petrocephalus': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Petrocephalus': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Petrocephalus': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Petrocephalus': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Petrocephalus': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Petrocephalus': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Petrocephalus': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Petrocephalus': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Petrocephalus': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Petrocephalus': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Petrocephalus': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Petrocephalus': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Petrocephalus': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Petrocephalus': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Petrocephalus': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Petrocephalus': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Petrocephalus': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Petrocephalus': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Brevimyrus': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Hyperopisus': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Stomatorhinus': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Campylomormyrus': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Campylomormyrus': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Campylomormyrus': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Campylomormyrus': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Campylomormyrus': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Campylomormyrus': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Campylomormyrus': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Campylomormyrus': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Campylomormyrus': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Campylomormyrus': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Gnathonemus': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Marcusenius': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Marcusenius': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Genyomyrus': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Cyphomyrus': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Hippopotamyrus': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Marcusenius': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Marcusenius': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Marcusenius': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Marcusenius': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Marcusenius': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Marcusenius': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Marcusenius': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Marcusenius': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Marcusenius': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Marcusenius': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Hippopotamyrus': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Hippopotamyrus': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Hippopotamyrus': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Hippopotamyrus': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Paramormyrops': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Paramormyrops': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Paramormyrops': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Paramormyrops': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Paramormyrops': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Paramormyrops': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Marcusenius': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Boulengeromyrus': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Ivindomyrus': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Ivindomyrus': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Pollimyrus': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Pollimyrus': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Pollimyrus': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Pollimyrus': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Pollimyrus': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Isichthys': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Brienomyrus': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Mormyrus': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Mormyrus': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Mormyrus': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Mormyrops': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Mormyrops': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Mormyrops': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Mormyrops': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Mormyrops': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Mormyrus': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Mormyrus': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Mormyrus': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Myomyrus': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Myomyrus': Order: Osteoglossiformes, Family: Mormyridae
# Cache hit for genus 'Notopterus': Order: Osteoglossiformes, Family: Notopteridae
# Cache hit for genus 'Chitala': Order: Osteoglossiformes, Family: Notopteridae
# Cache hit for genus 'Chitala': Order: Osteoglossiformes, Family: Notopteridae
# Cache hit for genus 'Chitala': Order: Osteoglossiformes, Family: Notopteridae
# Cache hit for genus 'Chitala': Order: Osteoglossiformes, Family: Notopteridae
# Cache hit for genus 'Xenomystus': Order: Osteoglossiformes, Family: Notopteridae
# Cache hit for genus 'Papyrocranus': Order: Osteoglossiformes, Family: Notopteridae
# Cache hit for genus 'Papyrocranus': Order: Osteoglossiformes, Family: Notopteridae
# Cache hit for genus 'Arapaima': Order: Osteoglossiformes, Family: Arapaimidae
# Cache hit for genus 'Heterotis': Order: Osteoglossiformes, Family: Arapaimidae
# Cache hit for genus 'Scleropages': Order: Osteoglossiformes, Family: Osteoglossidae
# Cache hit for genus 'Scleropages': Order: Osteoglossiformes, Family: Osteoglossidae
# Cache hit for genus 'Scleropages': Order: Osteoglossiformes, Family: Osteoglossidae
# Cache hit for genus 'Osteoglossum': Order: Osteoglossiformes, Family: Osteoglossidae
# Cache hit for genus 'Osteoglossum': Order: Osteoglossiformes, Family: Osteoglossidae
# Cache hit for genus 'Hiodon': Order: Osteoglossiformes, Family: Hiodontidae
# Cache hit for genus 'Hiodon': Order: Osteoglossiformes, Family: Hiodontidae
# Cache hit for genus 'Acipenser': Order: Acipenseriformes, Family: Acipenseridae
# Adding new order: Acipenseriformes
# Cache hit for genus 'Acipenser': Order: Acipenseriformes, Family: Acipenseridae
# Cache hit for genus 'Huso': Order: Acipenseriformes, Family: Acipenseridae
# Cache hit for genus 'Acipenser': Order: Acipenseriformes, Family: Acipenseridae
# Cache hit for genus 'Acipenser': Order: Acipenseriformes, Family: Acipenseridae
# Cache hit for genus 'Acipenser': Order: Acipenseriformes, Family: Acipenseridae
# Cache hit for genus 'Acipenser': Order: Acipenseriformes, Family: Acipenseridae
# Cache hit for genus 'Acipenser': Order: Acipenseriformes, Family: Acipenseridae
# Cache hit for genus 'Acipenser': Order: Acipenseriformes, Family: Acipenseridae
# Cache hit for genus 'Acipenser': Order: Acipenseriformes, Family: Acipenseridae
# Cache hit for genus 'Acipenser': Order: Acipenseriformes, Family: Acipenseridae
# Cache hit for genus 'Acipenser': Order: Acipenseriformes, Family: Acipenseridae
# Cache hit for genus 'Acipenser': Order: Acipenseriformes, Family: Acipenseridae
# Cache hit for genus 'Acipenser': Order: Acipenseriformes, Family: Acipenseridae
# Cache hit for genus 'Acipenser': Order: Acipenseriformes, Family: Acipenseridae
# Cache hit for genus 'Acipenser': Order: Acipenseriformes, Family: Acipenseridae
# Cache hit for genus 'Pseudoscaphirhynchus': Order: Acipenseriformes, Family: Acipenseridae
# Cache hit for genus 'Pseudoscaphirhynchus': Order: Acipenseriformes, Family: Acipenseridae
# Cache hit for genus 'Huso': Order: Acipenseriformes, Family: Acipenseridae
# Cache hit for genus 'Scaphirhynchus': Order: Acipenseriformes, Family: Acipenseridae
# Cache hit for genus 'Scaphirhynchus': Order: Acipenseriformes, Family: Acipenseridae
# Cache hit for genus 'Scaphirhynchus': Order: Acipenseriformes, Family: Acipenseridae
# Cache hit for genus 'Acipenser': Order: Acipenseriformes, Family: Acipenseridae
# Cache hit for genus 'Acipenser': Order: Acipenseriformes, Family: Acipenseridae
# Cache hit for genus 'Polyodon': Order: Acipenseriformes, Family: Polyodontidae
# Cache hit for genus 'Psephurus': Order: Acipenseriformes, Family: Polyodontidae
# Cache hit for genus 'Polypterus': Order: Polypteriformes, Family: Polypteridae
# Adding new order: Polypteriformes
# Cache hit for genus 'Polypterus': Order: Polypteriformes, Family: Polypteridae
# Cache hit for genus 'Polypterus': Order: Polypteriformes, Family: Polypteridae
# Cache hit for genus 'Polypterus': Order: Polypteriformes, Family: Polypteridae
# Cache hit for genus 'Polypterus': Order: Polypteriformes, Family: Polypteridae
# Cache hit for genus 'Polypterus': Order: Polypteriformes, Family: Polypteridae
# Cache hit for genus 'Polypterus': Order: Polypteriformes, Family: Polypteridae
# Cache hit for genus 'Polypterus': Order: Polypteriformes, Family: Polypteridae
# Cache hit for genus 'Polypterus': Order: Polypteriformes, Family: Polypteridae
# Cache hit for genus 'Polypterus': Order: Polypteriformes, Family: Polypteridae
# Cache hit for genus 'Polypterus': Order: Polypteriformes, Family: Polypteridae
# Cache hit for genus 'Polypterus': Order: Polypteriformes, Family: Polypteridae
# Cache hit for genus 'Polypterus': Order: Polypteriformes, Family: Polypteridae
# Cache hit for genus 'Erpetoichthys': Order: Polypteriformes, Family: Polypteridae

# %%
# Let's make a set of all the orders we found. For each leaf, get the order feature
# and add it to the set

found_orders = set()
for leaf in species_tree.get_leaves():
    found_orders.add(leaf.order)
print(f"Found {len(found_orders)} unique orders in the tree: {found_orders}")
for order in sorted(found_orders):
    print(f"- {order}")
# Out:
# Found 51 unique orders in the tree: {'Percopsiformes', 'Stomiiformes', 'Acanthuriformes', 'Stephanoberyciformes', 'Gadiformes', 'Gonorynchiformes', 'Argentiniformes', 'Beryciformes', 'Characiformes', 'Gasterosteiformes', 'Esociformes', 'Clupeiformes', 'Amiiformes', 'Scorpaeniformes', 'Gobiesociformes', 'Elopiformes', 'Tetraodontiformes', 'Beloniformes', 'Osmeriformes', 'Cyprinodontiformes', 'Saccopharyngiformes', 'Lepisosteiformes', 'Zeiformes', 'Cetomimiformes', 'Cichliformes', 'Polymixiiformes', 'Notacanthiformes', 'Perciformes', 'Albuliformes', 'Atheriniformes', 'Ateleopodiformes', 'Pleuronectiformes', 'Syngnathiformes', 'Lophiiformes', 'Acipenseriformes', 'Mugiliformes', 'Ophidiiformes', 'Polypteriformes', 'Centrarchiformes', 'Cypriniformes', 'Siluriformes', 'Batrachoidiformes', 'Gymnotiformes', 'Osteoglossiformes', 'Salmoniformes', 'Spariformes', 'Synbranchiformes', 'Lampriformes', 'Anguilliformes', 'Myctophiformes', 'Aulopiformes'}
# - Acanthuriformes
# - Acipenseriformes
# - Albuliformes
# - Amiiformes
# - Anguilliformes
# - Argentiniformes
# - Ateleopodiformes
# - Atheriniformes
# - Aulopiformes
# - Batrachoidiformes
# - Beloniformes
# - Beryciformes
# - Centrarchiformes
# - Cetomimiformes
# - Characiformes
# - Cichliformes
# - Clupeiformes
# - Cypriniformes
# - Cyprinodontiformes
# - Elopiformes
# - Esociformes
# - Gadiformes
# - Gasterosteiformes
# - Gobiesociformes
# - Gonorynchiformes
# - Gymnotiformes
# - Lampriformes
# - Lepisosteiformes
# - Lophiiformes
# - Mugiliformes
# - Myctophiformes
# - Notacanthiformes
# - Ophidiiformes
# - Osmeriformes
# - Osteoglossiformes
# - Perciformes
# - Percopsiformes
# - Pleuronectiformes
# - Polymixiiformes
# - Polypteriformes
# - Saccopharyngiformes
# - Salmoniformes
# - Scorpaeniformes
# - Siluriformes
# - Spariformes
# - Stephanoberyciformes
# - Stomiiformes
# - Synbranchiformes
# - Syngnathiformes
# - Tetraodontiformes
# - Zeiformes

# %%
# For looking up specific orders, e.g., Brassicales, that are not fish orders. These
# are fixed above in the database cleanup section.
for leaf in species_tree.get_leaves():
    if leaf.order == "Sulfolobales":
        print(f"Leaf in order Sulfolobales: {leaf.name}")

# %% [markdown]
# ## Monophyletic groups
#
# Every leaf has an order and family added. Let's find the order-level nodes in the tree and name those.

# %%
# For each insect order, find the corresponding leaves in the genus tree.
for order_name in found_orders:
    leaves_in_given_order = species_tree.search_nodes(order=order_name)
    print(f"Order {order_name} has {len(leaves_in_given_order)} leaves in the species tree.")

    # Now get the most recent common ancestor for these leaves.
    if leaves_in_given_order:
        mrca = species_tree.get_common_ancestor(leaves_in_given_order)
        print(f"The most recent common ancestor of order {order_name} is {mrca.name}.")
        mrca.name = order_name
        print(f"Renamed MRCA node to {mrca.name}.")
# Out:
# Order Percopsiformes has 12 leaves in the species tree.
# The most recent common ancestor of order Percopsiformes is 18528.
# Renamed MRCA node to Percopsiformes.
# Order Stomiiformes has 103 leaves in the species tree.
# The most recent common ancestor of order Stomiiformes is 19206.
# Renamed MRCA node to Stomiiformes.
# Order Acanthuriformes has 7 leaves in the species tree.
# The most recent common ancestor of order Acanthuriformes is 2839.
# Renamed MRCA node to Acanthuriformes.
# Order Stephanoberyciformes has 15 leaves in the species tree.
# The most recent common ancestor of order Stephanoberyciformes is 17963.
# Renamed MRCA node to Stephanoberyciformes.
# Order Gadiformes has 197 leaves in the species tree.
# The most recent common ancestor of order Gadiformes is 18462.
# Renamed MRCA node to Gadiformes.
# Order Gonorynchiformes has 14 leaves in the species tree.
# The most recent common ancestor of order Gonorynchiformes is 29413.
# Renamed MRCA node to Gonorynchiformes.
# Order Argentiniformes has 8 leaves in the species tree.
# The most recent common ancestor of order Argentiniformes is 83.
# Renamed MRCA node to Argentiniformes.
# Order Beryciformes has 77 leaves in the species tree.
# The most recent common ancestor of order Beryciformes is 18061.
# Renamed MRCA node to Beryciformes.
# Order Characiformes has 1019 leaves in the species tree.
# The most recent common ancestor of order Characiformes is 24029.
# Renamed MRCA node to Characiformes.
# Order Gasterosteiformes has 20 leaves in the species tree.
# The most recent common ancestor of order Gasterosteiformes is 17810.
# Renamed MRCA node to Gasterosteiformes.
# Order Esociformes has 12 leaves in the species tree.
# The most recent common ancestor of order Esociformes is 46.
# Renamed MRCA node to Esociformes.
# Order Clupeiformes has 185 leaves in the species tree.
# The most recent common ancestor of order Clupeiformes is 29674.
# Renamed MRCA node to Clupeiformes.
# Order Amiiformes has 1 leaves in the species tree.
# The most recent common ancestor of order Amiiformes is .
# Renamed MRCA node to Amiiformes.
# Order Scorpaeniformes has 547 leaves in the species tree.
# The most recent common ancestor of order Scorpaeniformes is Gasterosteiformes.
# Renamed MRCA node to Scorpaeniformes.
# Order Gobiesociformes has 53 leaves in the species tree.
# The most recent common ancestor of order Gobiesociformes is 13988.
# Renamed MRCA node to Gobiesociformes.
# Order Elopiformes has 7 leaves in the species tree.
# The most recent common ancestor of order Elopiformes is 29850.
# Renamed MRCA node to Elopiformes.
# Order Tetraodontiformes has 267 leaves in the species tree.
# The most recent common ancestor of order Tetraodontiformes is 2283.
# Renamed MRCA node to Tetraodontiformes.
# Order Beloniformes has 131 leaves in the species tree.
# The most recent common ancestor of order Beloniformes is 11607.
# Renamed MRCA node to Beloniformes.
# Order Osmeriformes has 142 leaves in the species tree.
# The most recent common ancestor of order Osmeriformes is 29845.
# Renamed MRCA node to Osmeriformes.
# Order Cyprinodontiformes has 809 leaves in the species tree.
# The most recent common ancestor of order Cyprinodontiformes is 13233.
# Renamed MRCA node to Cyprinodontiformes.
# Order Saccopharyngiformes has 5 leaves in the species tree.
# The most recent common ancestor of order Saccopharyngiformes is 29931.
# Renamed MRCA node to Saccopharyngiformes.
# Order Lepisosteiformes has 7 leaves in the species tree.
# The most recent common ancestor of order Lepisosteiformes is 35.
# Renamed MRCA node to Lepisosteiformes.
# Order Zeiformes has 28 leaves in the species tree.
# The most recent common ancestor of order Zeiformes is 18535.
# Renamed MRCA node to Zeiformes.
# Order Cetomimiformes has 13 leaves in the species tree.
# The most recent common ancestor of order Cetomimiformes is 17977.
# Renamed MRCA node to Cetomimiformes.
# Order Cichliformes has 7 leaves in the species tree.
# The most recent common ancestor of order Cichliformes is 9642.
# Renamed MRCA node to Cichliformes.
# Order Polymixiiformes has 4 leaves in the species tree.
# The most recent common ancestor of order Polymixiiformes is 18520.
# Renamed MRCA node to Polymixiiformes.
# Order Notacanthiformes has 9 leaves in the species tree.
# The most recent common ancestor of order Notacanthiformes is 29876.
# Renamed MRCA node to Notacanthiformes.
# Order Perciformes has 5731 leaves in the species tree.
# The most recent common ancestor of order Perciformes is Scorpaeniformes.
# Renamed MRCA node to Perciformes.
# Order Albuliformes has 8 leaves in the species tree.
# The most recent common ancestor of order Albuliformes is 28281.
# Renamed MRCA node to Albuliformes.
# Order Atheriniformes has 250 leaves in the species tree.
# The most recent common ancestor of order Atheriniformes is 11262.
# Renamed MRCA node to Atheriniformes.
# Order Ateleopodiformes has 6 leaves in the species tree.
# The most recent common ancestor of order Ateleopodiformes is 18993.
# Renamed MRCA node to Ateleopodiformes.
# Order Pleuronectiformes has 328 leaves in the species tree.
# The most recent common ancestor of order Pleuronectiformes is 8451.
# Renamed MRCA node to Pleuronectiformes.
# Order Syngnathiformes has 210 leaves in the species tree.
# The most recent common ancestor of order Syngnathiformes is 17800.
# Renamed MRCA node to Syngnathiformes.
# Order Lophiiformes has 113 leaves in the species tree.
# The most recent common ancestor of order Lophiiformes is 2557.
# Renamed MRCA node to Lophiiformes.
# Order Acipenseriformes has 26 leaves in the species tree.
# The most recent common ancestor of order Acipenseriformes is 30581.
# Renamed MRCA node to Acipenseriformes.
# Order Mugiliformes has 64 leaves in the species tree.
# The most recent common ancestor of order Mugiliformes is 14943.
# Renamed MRCA node to Mugiliformes.
# Order Ophidiiformes has 64 leaves in the species tree.
# The most recent common ancestor of order Ophidiiformes is 414.
# Renamed MRCA node to Ophidiiformes.
# Order Polypteriformes has 14 leaves in the species tree.
# The most recent common ancestor of order Polypteriformes is 30602.
# Renamed MRCA node to Polypteriformes.
# Order Centrarchiformes has 1 leaves in the species tree.
# The most recent common ancestor of order Centrarchiformes is Amiiformes.
# Renamed MRCA node to Centrarchiformes.
# Order Cypriniformes has 1878 leaves in the species tree.
# The most recent common ancestor of order Cypriniformes is 29398.
# Renamed MRCA node to Cypriniformes.
# Order Siluriformes has 1891 leaves in the species tree.
# The most recent common ancestor of order Siluriformes is 23509.
# Renamed MRCA node to Siluriformes.
# Order Batrachoidiformes has 20 leaves in the species tree.
# The most recent common ancestor of order Batrachoidiformes is 17833.
# Renamed MRCA node to Batrachoidiformes.
# Order Gymnotiformes has 176 leaves in the species tree.
# The most recent common ancestor of order Gymnotiformes is 19755.
# Renamed MRCA node to Gymnotiformes.
# Order Osteoglossiformes has 103 leaves in the species tree.
# The most recent common ancestor of order Osteoglossiformes is 30523.
# Renamed MRCA node to Osteoglossiformes.
# Order Salmoniformes has 89 leaves in the species tree.
# The most recent common ancestor of order Salmoniformes is 275.
# Renamed MRCA node to Salmoniformes.
# Order Spariformes has 1 leaves in the species tree.
# The most recent common ancestor of order Spariformes is Centrarchiformes.
# Renamed MRCA node to Spariformes.
# Order Synbranchiformes has 49 leaves in the species tree.
# The most recent common ancestor of order Synbranchiformes is 7547.
# Renamed MRCA node to Synbranchiformes.
# Order Lampriformes has 16 leaves in the species tree.
# The most recent common ancestor of order Lampriformes is 18577.
# Renamed MRCA node to Lampriformes.
# Order Anguilliformes has 228 leaves in the species tree.
# The most recent common ancestor of order Anguilliformes is 30324.
# Renamed MRCA node to Anguilliformes.
# Order Myctophiformes has 130 leaves in the species tree.
# The most recent common ancestor of order Myctophiformes is 18506.
# Renamed MRCA node to Myctophiformes.
# Order Aulopiformes has 78 leaves in the species tree.
# The most recent common ancestor of order Aulopiformes is 18978.
# Renamed MRCA node to Aulopiformes.

# %%
# Finally, let's save the cleaned species tree to a file.
species_tree.write(format=1, outfile='output/Actinopterygii_species_with_order.nwk')

# %% [markdown]
# # Tree of orders
#
# We do need a tree that shows the relationships between the different orders. This is used in subsequent notebooks to build a scaffold tree that will have the points grafted onto it. See the insect dataset for more info on this.
#
# <b>IMPORTANT</b>
#
# You *can* generate an order-level tree directly from the timetree.org site, however it usually is paraphyletic; certain orders show up multiple times in the tree and it requires extensive cleaning (and knowledge of fish phylogenetics, which I do not have). So we will use the species-level tree from timetree to generate monophyletic order-level groupings and then generate an order-level tree from there.

# %%
# For each order, pick one leaf at random and print the leaf name, order, and family.

# Let's start with a full copy of the original tree that we can prune.
fish_tree_order_level = species_tree.copy()

fishes_to_keep = []

import random
for order in found_orders:
    leaves_in_order = fish_tree_order_level.search_nodes(order=order)
    if leaves_in_order:
        random_leaf = random.choice(leaves_in_order)
        fishes_to_keep.append(random_leaf)

# Now prune the tree to keep only these leaves.
fish_tree_order_level.prune(fishes_to_keep, preserve_branch_length=True)

# Now change the tip names to just the order name.
for leaf in fish_tree_order_level.get_leaves():
    leaf.name = leaf.order

# Now make sure any internal nodes that have the same name as a leaf are renamed to something else.
for node in fish_tree_order_level.traverse():
    if node.is_leaf():
        continue
    if node.name in found_orders:
        node.name = f"{node.name}_internal"

print(f'Order-level tree has {len(fish_tree_order_level.get_leaves())} tips.')
print(fish_tree_order_level)
# Out:
# Order-level tree has 51 tips.
#
#             /-Amiiformes
#          /-|
#         |   \-Lepisosteiformes
#         |
#         |                        /-Siluriformes
#         |                     /-|
#         |                  /-|   \-Characiformes
#         |                 |  |
#         |               /-|   \-Gymnotiformes
#         |              |  |
#         |            /-|   \-Cypriniformes
#         |           |  |
#         |         /-|   \-Gonorynchiformes
#         |        |  |
#         |        |   \-Clupeiformes
#         |        |
#         |        |         /-Esociformes
#         |        |      /-|
#         |        |   /-|   \-Salmoniformes
#         |        |  |  |
#         |        |  |   \-Argentiniformes
#         |        |  |
#         |        |  |                                             /-Spariformes
#         |        |  |                                          /-|
#         |        |  |                                         |  |   /-Tetraodontiformes
#         |        |  |                                       /-|   \-|
#         |        |  |                                      |  |      \-Lophiiformes
#         |        |  |                                    /-|  |
#         |        |  |                                   |  |   \-Acanthuriformes
#         |        |  |                                   |  |
#         |      /-|  |                                 /-|   \-Centrarchiformes
#         |     |  |  |                                |  |
#         |     |  |  |                                |  |   /-Perciformes
#         |     |  |  |                                |   \-|
#         |     |  |  |                                |     |   /-Gasterosteiformes
#         |     |  |  |                                |      \-|
#         |     |  |  |                              /-|         \-Scorpaeniformes
#         |     |  |  |                             |  |
#         |     |  |  |                             |  |      /-Synbranchiformes
#       /-|     |  |  |                             |  |   /-|
#      |  |     |  |  |                             |  |  |   \-Pleuronectiformes
#      |  |     |  |  |                             |  |  |
#      |  |     |  |  |                             |  |  |            /-Beloniformes
#      |  |     |  |  |                             |   \-|         /-|
#      |  |     |  |  |                             |     |      /-|   \-Cyprinodontiformes
#      |  |     |  |  |                           /-|     |     |  |
#      |  |     |  |  |                          |  |     |   /-|   \-Atheriniformes
#      |  |     |  |  |                          |  |     |  |  |
#      |  |     |  |  |                          |  |      \-|   \-Cichliformes
#      |  |     |   \-|                          |  |        |
#      |  |     |     |                        /-|  |        |   /-Gobiesociformes
#      |  |     |     |                       |  |  |         \-|
#      |  |     |     |                       |  |  |            \-Mugiliformes
#      |  |     |     |                       |  |  |
#      |  |     |     |                     /-|  |   \-Syngnathiformes
#      |  |     |     |                    |  |  |
#      |  |     |     |                    |  |   \-Batrachoidiformes
#      |  |     |     |                    |  |
#      |  |     |     |                  /-|   \-Ophidiiformes
#      |  |     |     |                 |  |
#      |  |   /-|     |                 |  |      /-Stephanoberyciformes
#      |  |  |  |     |                 |  |   /-|
#      |  |  |  |     |               /-|   \-|   \-Cetomimiformes
#      |  |  |  |     |              |  |     |
#      |  |  |  |     |              |  |      \-Beryciformes
#      |  |  |  |     |              |  |
#      |  |  |  |     |              |   \-Lampriformes
#      |  |  |  |     |            /-|
#    /-|  |  |  |     |           |  |         /-Gadiformes
#   |  |  |  |  |     |           |  |      /-|
#   |  |  |  |  |     |           |  |   /-|   \-Zeiformes
#   |  |  |  |  |     |         /-|  |  |  |
#   |  |  |  |  |     |        |  |   \-|   \-Percopsiformes
#   |  |  |  |  |     |        |  |     |
#   |  |  |  |  |     |      /-|  |      \-Polymixiiformes
#   |  |  |  |  |     |     |  |  |
#   |  |  |  |  |     |     |  |   \-Myctophiformes
#   |  |  |  |  |     |   /-|  |
#   |  |   \-|  |     |  |  |   \-Aulopiformes
#   |  |     |  |     |  |  |
#   |  |     |  |      \-|   \-Ateleopodiformes
#   |  |     |  |        |
#   |  |     |  |        |   /-Osmeriformes
#   |  |     |  |         \-|
# --|  |     |  |            \-Stomiiformes
#   |  |     |  |
#   |  |     |  |         /-Notacanthiformes
#   |  |     |  |      /-|
#   |  |     |  |     |  |   /-Anguilliformes
#   |  |     |  |   /-|   \-|
#   |  |     |  |  |  |      \-Saccopharyngiformes
#   |  |     |   \-|  |
#   |  |     |     |   \-Albuliformes
#   |  |     |     |
#   |  |     |      \-Elopiformes
#   |  |     |
#   |  |      \-Osteoglossiformes
#   |  |
#   |   \-Acipenseriformes
#   |
#    \-Polypteriformes

# %%
# Looks good, let's save the order-level tree to a file.
fish_tree_order_level.write(format=1, outfile="output/Actinopterygii_order_level.nwk")
# Let's load it back in to make sure it saved correctly.
order_level_tree = Tree("output/Actinopterygii_order_level.nwk", format=1, quoted_node_names=True)
print(order_level_tree)
# Out:
#             /-Amiiformes
#          /-|
#         |   \-Lepisosteiformes
#         |
#         |                        /-Siluriformes
#         |                     /-|
#         |                  /-|   \-Characiformes
#         |                 |  |
#         |               /-|   \-Gymnotiformes
#         |              |  |
#         |            /-|   \-Cypriniformes
#         |           |  |
#         |         /-|   \-Gonorynchiformes
#         |        |  |
#         |        |   \-Clupeiformes
#         |        |
#         |        |         /-Esociformes
#         |        |      /-|
#         |        |   /-|   \-Salmoniformes
#         |        |  |  |
#         |        |  |   \-Argentiniformes
#         |        |  |
#         |        |  |                                             /-Spariformes
#         |        |  |                                          /-|
#         |        |  |                                         |  |   /-Tetraodontiformes
#         |        |  |                                       /-|   \-|
#         |        |  |                                      |  |      \-Lophiiformes
#         |        |  |                                    /-|  |
#         |        |  |                                   |  |   \-Acanthuriformes
#         |        |  |                                   |  |
#         |      /-|  |                                 /-|   \-Centrarchiformes
#         |     |  |  |                                |  |
#         |     |  |  |                                |  |   /-Perciformes
#         |     |  |  |                                |   \-|
#         |     |  |  |                                |     |   /-Gasterosteiformes
#         |     |  |  |                                |      \-|
#         |     |  |  |                              /-|         \-Scorpaeniformes
#         |     |  |  |                             |  |
#         |     |  |  |                             |  |      /-Synbranchiformes
#       /-|     |  |  |                             |  |   /-|
#      |  |     |  |  |                             |  |  |   \-Pleuronectiformes
#      |  |     |  |  |                             |  |  |
#      |  |     |  |  |                             |  |  |            /-Beloniformes
#      |  |     |  |  |                             |   \-|         /-|
#      |  |     |  |  |                             |     |      /-|   \-Cyprinodontiformes
#      |  |     |  |  |                           /-|     |     |  |
#      |  |     |  |  |                          |  |     |   /-|   \-Atheriniformes
#      |  |     |  |  |                          |  |     |  |  |
#      |  |     |  |  |                          |  |      \-|   \-Cichliformes
#      |  |     |   \-|                          |  |        |
#      |  |     |     |                        /-|  |        |   /-Gobiesociformes
#      |  |     |     |                       |  |  |         \-|
#      |  |     |     |                       |  |  |            \-Mugiliformes
#      |  |     |     |                       |  |  |
#      |  |     |     |                     /-|  |   \-Syngnathiformes
#      |  |     |     |                    |  |  |
#      |  |     |     |                    |  |   \-Batrachoidiformes
#      |  |     |     |                    |  |
#      |  |     |     |                  /-|   \-Ophidiiformes
#      |  |     |     |                 |  |
#      |  |   /-|     |                 |  |      /-Stephanoberyciformes
#      |  |  |  |     |                 |  |   /-|
#      |  |  |  |     |               /-|   \-|   \-Cetomimiformes
#      |  |  |  |     |              |  |     |
#      |  |  |  |     |              |  |      \-Beryciformes
#      |  |  |  |     |              |  |
#      |  |  |  |     |              |   \-Lampriformes
#      |  |  |  |     |            /-|
#    /-|  |  |  |     |           |  |         /-Gadiformes
#   |  |  |  |  |     |           |  |      /-|
#   |  |  |  |  |     |           |  |   /-|   \-Zeiformes
#   |  |  |  |  |     |         /-|  |  |  |
#   |  |  |  |  |     |        |  |   \-|   \-Percopsiformes
#   |  |  |  |  |     |        |  |     |
#   |  |  |  |  |     |      /-|  |      \-Polymixiiformes
#   |  |  |  |  |     |     |  |  |
#   |  |  |  |  |     |     |  |   \-Myctophiformes
#   |  |  |  |  |     |   /-|  |
#   |  |   \-|  |     |  |  |   \-Aulopiformes
#   |  |     |  |     |  |  |
#   |  |     |  |      \-|   \-Ateleopodiformes
#   |  |     |  |        |
#   |  |     |  |        |   /-Osmeriformes
#   |  |     |  |         \-|
# --|  |     |  |            \-Stomiiformes
#   |  |     |  |
#   |  |     |  |         /-Notacanthiformes
#   |  |     |  |      /-|
#   |  |     |  |     |  |   /-Anguilliformes
#   |  |     |  |   /-|   \-|
#   |  |     |  |  |  |      \-Saccopharyngiformes
#   |  |     |   \-|  |
#   |  |     |     |   \-Albuliformes
#   |  |     |     |
#   |  |     |      \-Elopiformes
#   |  |     |
#   |  |      \-Osteoglossiformes
#   |  |
#   |   \-Acipenseriformes
#   |
#    \-Polypteriformes

# %% [markdown]
# Let's make a CSV file that has the following columns for use in later notebooks:
#
# - genus
# - order
# - family
# - taxon

# %%
import pandas as pd
genus_order_family_df = pd.DataFrame(columns=['genus', 'order', 'family', 'taxon'])

for leaf in species_tree.get_leaves():
    genus_name = re.split(r'[ _-]', leaf.name)[0]

    order_name = leaf.order
    family_name = db.get_species_info(genus_name, verbose=False)[1]
    genus_order_family_df.loc[len(genus_order_family_df)] = [genus_name, order_name, family_name, leaf.name]

# Save this list to a file.
genus_order_family_df.to_csv('output/Actinopterygii_genus_order_family_taxon.csv', index=False)

# %% [markdown]
# # Tree of families.
#
# Let's do the same thing for families. We'll use this to build a scaffold, similar to the order-level tree, but using monophyletic families.

# %%
# First let's get a list of all the unique families in the tree.
unique_families = set()
for leaf in species_tree.get_leaves():
    unique_families.add(leaf.family)
print(f"Found {len(unique_families)} unique families in the tree.")
for family in sorted(unique_families):
    print(f"- {family}")

# %% [markdown]
# # Family-level statistics
#
# The cells below do some histograms to get counts of taxa in families, etc. These are not needed for making OpenSpace assets, etc.

# %%
# Let's show a barplot of the number of leaves per order. Add the number of leaves on top of each bar.
import matplotlib.pyplot as plt
order_counts = {order: len([leaf for leaf in species_tree.get_leaves() if leaf.order == order]) for order in found_orders}
# Put these in alphabetical order.
#order_counts = dict(sorted(order_counts.items()))
plt.figure(figsize=(10, 6))
bars = plt.bar(order_counts.keys(), order_counts.values())
plt.xticks(rotation=90)
plt.xlabel('Order')
plt.ylabel('Number of Leaves')

# Add the number of leaves on top of each bar.
for bar in bars:
    yval = bar.get_height()
    #plt.text(bar.get_x() + bar.get_width()/2, yval, int(yval), va='bottom')  # va: vertical alignment
    plt.text(bar.get_x(), yval, int(yval), va='bottom')  # va: vertical alignment
plt.title('Number of Leaves per Order in Species Tree')
plt.tight_layout()
plt.show()

# %%
# How many unique families in each order? Let's make a barplot.
unique_families_per_order = genus_order_family_df.groupby('order')['family'].nunique()

# Change the order of the list to match the found_orders list of fish orders
unique_families_per_order = unique_families_per_order.reindex(found_orders)

import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.bar(unique_families_per_order.index, unique_families_per_order.values)
plt.xticks(rotation=90)
plt.title('Number of Unique Families per Order')
plt.xlabel('Order')
plt.ylabel('Number of Unique Families')
plt.tight_layout()
plt.show()
